# %%
from os import environ
from pathlib import Path
from sys import executable

import numpy as np
import plotly.express as px
import plotly.io as pio
from geopy.distance import geodesic
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.stat import Correlation
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import StringType, DoubleType

# %%
pio.renderers.default = "notebook_connected"

environ['PYSPARK_PYTHON'] = executable
environ['PYSPARK_DRIVER_PYTHON'] = executable

spark = SparkSession \
    .builder \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memory", "1g") \
    .config("spark.sql.shuffle.partitions", "20") \
    .getOrCreate()

# %%
df_path = Path.cwd().parent / "data" / "dataframe"
df = spark.read.parquet(str(df_path))

# %%
df.show(5)
# Out:
# +---------+--------------+--------------+---------------+----------------+-----------------+---------------------+------------+---------------+-------------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+
# |flight_id|target_economy|target_comfort|target_business|  departure_city|departure_country|departure_coordinates|arrival_city|arrival_country|arrival_coordinates|departure_year|departure_month|departure_day|departure_day_of_week|is_weekend|departure_hour|departure_minute|duration_hours|duration_minutes|count_of_week_routes|   airplane_model|airplane_range|airplane_speed|economy|comfort|business|all_seats|avg_book_lead_time|min_book_lead_time|max_book_lead_time|  s2_book_lead_time|count_book_lead_time|
# +---------+--------------+--------------+---------------+----------------+-----------------+---------------------+------------+---------------+-------------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+
# |       29|           326|            48|             30|           Paris|           France|      [2.55, 49.0128]|        Nice|         France|  [7.2159, 43.6584]|          2025|             10|            1|                    3|     false|             5|              20|             1|              20|                   7| Boeing 777-300ER|         14600|           905|    326|     48|      30|      404|30.120028891673627|30.006631944444443| 30.21943287037037|0.05985291147778805|                 133|
# |       30|           115|             0|             13|         Beijing|            China|   [116.585, 40.0801]|         Goa|          India| [73.8314, 15.3808]|          2025|             10|            1|                    3|     false|             5|              25|             7|               0|                   1| Boeing 737 MAX 7|          7000|           840|    144|      0|      16|      160|30.123078703703705|30.064328703703705|30.181828703703705|0.08308504678941933|                   2|
# |       44|           144|             0|             16|           Miami|    United States|  [-80.2906, 25.7932]|   Charlotte|  United States| [-80.9431, 35.214]|          2025|             10|            1|                    3|     false|             7|              25|             1|              50|                   6| Boeing 737 MAX 7|          7000|           840|    144|      0|      16|      160|30.177904128086418|30.019814814814815|30.307986111111113|0.09870410648688327|                  24|
# |       54|           281|             0|             44|Saint Petersburg|           Russia|   [30.2625, 59.8003]|      Moscow|         Russia| [37.4146, 55.9726]|          2025|             10|            1|                    3|     false|             8|              20|             1|              15|                   7|Aerobus A350-1000|         16700|           913|    281|      0|      44|      325|30.152721522394486|30.003888888888888|30.342453703703704|0.09039887194550104|                  43|
# |       99|           281|             0|             44|         Orlando|    United States|   [-81.309, 28.4294]|     Atlanta|  United States|[-84.4281, 33.6367]|          2025|             10|            1|                    3|     false|            13|              35|             1|              15|                   6|Aerobus A350-1000|         16700|           913|    281|      0|      44|      325|30.292628451554236|30.010856481481483|        30.5603125|0.16560835852028494|                 112|
# +---------+--------------+--------------+---------------+----------------+-----------------+---------------------+------------+---------------+-------------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- flight_id: integer (nullable = true)
#  |-- target_economy: long (nullable = true)
#  |-- target_comfort: long (nullable = true)
#  |-- target_business: long (nullable = true)
#  |-- departure_city: string (nullable = true)
#  |-- departure_country: string (nullable = true)
#  |-- departure_coordinates: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- arrival_city: string (nullable = true)
#  |-- arrival_country: string (nullable = true)
#  |-- arrival_coordinates: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- departure_year: integer (nullable = true)
#  |-- departure_month: integer (nullable = true)
#  |-- departure_day: integer (nullable = true)
#  |-- departure_day_of_week: integer (nullable = true)
#  |-- is_weekend: boolean (nullable = true)
#  |-- departure_hour: integer (nullable = true)
#  |-- departure_minute: integer (nullable = true)
#  |-- duration_hours: integer (nullable = true)
#  |-- duration_minutes: integer (nullable = true)
#  |-- count_of_week_routes: integer (nullable = true)
#  |-- airplane_model: string (nullable = true)
#  |-- airplane_range: integer (nullable = true)
#  |-- airplane_speed: integer (nullable = true)
#  |-- economy: long (nullable = true)
#  |-- comfort: long (nullable = true)
#  |-- business: long (nullable = true)
#  |-- all_seats: long (nullable = true)
#  |-- avg_book_lead_time: double (nullable = true)
#  |-- min_book_lead_time: double (nullable = true)
#  |-- max_book_lead_time: double (nullable = true)
#  |-- s2_book_lead_time: double (nullable = true)
#  |-- count_book_lead_time: long (nullable = true)

# %%
distance_lambda = F.udf(lambda coord1, coord2: geodesic(coord1[::-1], coord2[::-1]).km, DoubleType())

df = df \
    .withColumn('distance', distance_lambda('departure_coordinates', 'arrival_coordinates')) \
    .drop('departure_coordinates', 'arrival_coordinates')

# %%
df.printSchema()
# Out:
# root
#  |-- flight_id: integer (nullable = true)
#  |-- target_economy: long (nullable = true)
#  |-- target_comfort: long (nullable = true)
#  |-- target_business: long (nullable = true)
#  |-- departure_city: string (nullable = true)
#  |-- departure_country: string (nullable = true)
#  |-- arrival_city: string (nullable = true)
#  |-- arrival_country: string (nullable = true)
#  |-- departure_year: integer (nullable = true)
#  |-- departure_month: integer (nullable = true)
#  |-- departure_day: integer (nullable = true)
#  |-- departure_day_of_week: integer (nullable = true)
#  |-- is_weekend: boolean (nullable = true)
#  |-- departure_hour: integer (nullable = true)
#  |-- departure_minute: integer (nullable = true)
#  |-- duration_hours: integer (nullable = true)
#  |-- duration_minutes: integer (nullable = true)
#  |-- count_of_week_routes: integer (nullable = true)
#  |-- airplane_model: string (nullable = true)
#  |-- airplane_range: integer (nullable = true)
#  |-- airplane_speed: integer (nullable = true)
#  |-- economy: long (nullable = true)
#  |-- comfort: long (nullable = true)
#  |-- business: long (nullable = true)
#  |-- all_seats: long (nullable = true)
#  |-- avg_book_lead_time: double (nullable = true)
#  |-- min_book_lead_time: double (nullable = true)
#  |-- max_book_lead_time: double (nullable = true)
#  |-- s2_book_lead_time: double (nullable = true)
#  |-- count_book_lead_time: long (nullable = true)
#  |-- distance: double (nullable = true)

# %%
all_features = df.columns
cat_features = [feature.name for feature in df.schema if isinstance(feature.dataType, StringType)]
noncat_features = [feature.name for feature in df.schema if not isinstance(feature.dataType, StringType)]

print(f'Categorical features: {cat_features}')
print(f'Non-categorical features: {noncat_features}')

bool_replace = [col for col, dtype in df.dtypes if dtype == 'boolean']
df = df.withColumns({col: F.col(col).cast('int') for col in bool_replace})
# Out:
# Categorical features: ['departure_city', 'departure_country', 'arrival_city', 'arrival_country', 'airplane_model']
# Non-categorical features: ['flight_id', 'target_economy', 'target_comfort', 'target_business', 'departure_year', 'departure_month', 'departure_day', 'departure_day_of_week', 'is_weekend', 'departure_hour', 'departure_minute', 'duration_hours', 'duration_minutes', 'count_of_week_routes', 'airplane_range', 'airplane_speed', 'economy', 'comfort', 'business', 'all_seats', 'avg_book_lead_time', 'min_book_lead_time', 'max_book_lead_time', 's2_book_lead_time', 'count_book_lead_time', 'distance']

# %%
null_and_nan_cols = [
    col
    for col, count in df \
        .select(
            [F.count(F.when(F.isnull(col) | F.isnan(col), col)).alias(col) for col in noncat_features] +
            [F.count(F.when(F.isnull(col), col)).alias(col) for col in cat_features]
        ) \
        .first() \
        .asDict() \
        .items()
    if count > 0
]

print(f'cols with null or nan values: {null_and_nan_cols}')
# Out:
# cols with null or nan values: ['avg_book_lead_time', 'min_book_lead_time', 'max_book_lead_time', 's2_book_lead_time', 'count_book_lead_time']

# %% [markdown]
# т.к. физический смысл данных может иметь разное значение, то и обрабатывать каждую из этих колонок надо отдельно <br>
# `count_book_lead_time` заменить на 0, потому что null или nan означает отсутствие броней, то есть 0 <br>
# для остальный колоном можно добавить колонку `заменено ли это значение` и заменить на 0, чтобы в будущей модель лучше понимала реальное ли это значение или нет <br>
# замена на 0 происходит из-за того, что это данные уже динамические, которые считаются из количества билетов, которые люди купили за 30 дней до рейса. Заменять их на другие значение означает, что мы даем не реальные данные

# %%
for col in null_and_nan_cols:
    if col == 'count_book_lead_time':
        df = df.fillna({col: 0})
    else:
        df = df.withColumn(f"is_{col}_missing", F.when(F.isnan(col) | F.isnull(col), 1).otherwise(0))   # все колонки это числовые значение
        df = df.fillna({col: 0})

df.show(5)
# Out:
# +---------+--------------+--------------+---------------+----------------+-----------------+------------+---------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+-----------------+-----------------------------+-----------------------------+-----------------------------+----------------------------+
# |flight_id|target_economy|target_comfort|target_business|  departure_city|departure_country|arrival_city|arrival_country|departure_year|departure_month|departure_day|departure_day_of_week|is_weekend|departure_hour|departure_minute|duration_hours|duration_minutes|count_of_week_routes|   airplane_model|airplane_range|airplane_speed|economy|comfort|business|all_seats|avg_book_lead_time|min_book_lead_time|max_book_lead_time|  s2_book_lead_time|count_book_lead_time|         distance|is_avg_book_lead_time_missing|is_min_book_lead_time_missing|is_max_book_lead_time_missing|is_s2_book_lead_time_missing|
# +---------+--------------+--------------+---------------+----------------+-----------------+------------+---------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+-----------------+-----------------------------+-----------------------------+-----------------------------+----------------------------+
# |       29|           326|            48|             30|           Paris|           France|        Nice|         France|          2025|             10|            1|                    3|         0|             5|              20|             1|              20|                   7| Boeing 777-300ER|         14600|           905|    326|     48|      30|      404|30.120028891673627|30.006631944444443| 30.21943287037037|0.05985291147778805|                 133|694.8803418152029|                            0|                            0|                            0|                           0|
# |       30|           115|             0|             13|         Beijing|            China|         Goa|          India|          2025|             10|            1|                    3|         0|             5|              25|             7|               0|                   1| Boeing 737 MAX 7|          7000|           840|    144|      0|      16|      160|30.123078703703705|30.064328703703705|30.181828703703705|0.08308504678941933|                   2| 4956.46820072746|                            0|                            0|                            0|                           0|
# |       44|           144|             0|             16|           Miami|    United States|   Charlotte|  United States|          2025|             10|            1|                    3|         0|             7|              25|             1|              50|                   6| Boeing 737 MAX 7|          7000|           840|    144|      0|      16|      160|30.177904128086418|30.019814814814815|30.307986111111113|0.09870410648688327|                  24| 1046.27861637211|                            0|                            0|                            0|                           0|
# |       54|           281|             0|             44|Saint Petersburg|           Russia|      Moscow|         Russia|          2025|             10|            1|                    3|         0|             8|              20|             1|              15|                   7|Aerobus A350-1000|         16700|           913|    281|      0|      44|      325|30.152721522394486|30.003888888888888|30.342453703703704|0.09039887194550104|                  43| 600.828584580228|                            0|                            0|                            0|                           0|
# |       99|           281|             0|             44|         Orlando|    United States|     Atlanta|  United States|          2025|             10|            1|                    3|         0|            13|              35|             1|              15|                   6|Aerobus A350-1000|         16700|           913|    281|      0|      44|      325|30.292628451554236|30.010856481481483|        30.5603125|0.16560835852028494|                 112|649.5064290488112|                            0|                            0|                            0|                           0|
# +---------+--------------+--------------+---------------+----------------+-----------------+------------+---------------+--------------+---------------+-------------+---------------------+----------+--------------+----------------+--------------+----------------+--------------------+-----------------+--------------+--------------+-------+-------+--------+---------+------------------+------------------+------------------+-------------------+--------------------+-----------------+-----------------------------+-----------------------------+-----------------------------+----------------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- flight_id: integer (nullable = true)
#  |-- target_economy: long (nullable = true)
#  |-- target_comfort: long (nullable = true)
#  |-- target_business: long (nullable = true)
#  |-- departure_city: string (nullable = true)
#  |-- departure_country: string (nullable = true)
#  |-- arrival_city: string (nullable = true)
#  |-- arrival_country: string (nullable = true)
#  |-- departure_year: integer (nullable = true)
#  |-- departure_month: integer (nullable = true)
#  |-- departure_day: integer (nullable = true)
#  |-- departure_day_of_week: integer (nullable = true)
#  |-- is_weekend: integer (nullable = true)
#  |-- departure_hour: integer (nullable = true)
#  |-- departure_minute: integer (nullable = true)
#  |-- duration_hours: integer (nullable = true)
#  |-- duration_minutes: integer (nullable = true)
#  |-- count_of_week_routes: integer (nullable = true)
#  |-- airplane_model: string (nullable = true)
#  |-- airplane_range: integer (nullable = true)
#  |-- airplane_speed: integer (nullable = true)
#  |-- economy: long (nullable = true)
#  |-- comfort: long (nullable = true)
#  |-- business: long (nullable = true)
#  |-- all_seats: long (nullable = true)
#  |-- avg_book_lead_time: double (nullable = false)
#  |-- min_book_lead_time: double (nullable = false)
#  |-- max_book_lead_time: double (nullable = false)
#  |-- s2_book_lead_time: double (nullable = false)
#  |-- count_book_lead_time: long (nullable = false)
#  |-- distance: double (nullable = true)
#  |-- is_avg_book_lead_time_missing: integer (nullable = false)
#  |-- is_min_book_lead_time_missing: integer (nullable = false)
#  |-- is_max_book_lead_time_missing: integer (nullable = false)
#  |-- is_s2_book_lead_time_missing: integer (nullable = false)

# %% [markdown]
# работа с пропусками и со значениями типа boolean завершена <br>
# теперь можно переходить к самому анализу данных

# %%
target_classes = df \
    .select(
        F.sum("target_economy").alias("economy"),
        F.sum("target_comfort").alias("comfort"),
        F.sum("target_business").alias("business")
    )
fig = px.bar(x=target_classes.columns, y=target_classes.collect(), title='Fare Conditions Distribution', labels={'x': 'Ticket classes', 'y': 'Ticket amount'}).update_layout(showlegend=False)
fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="53ea5369-f425-4caf-88e7-adfa228d8faf" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("53ea5369-f425-4caf-88e7-adfa228d8faf")) {                    Plotly.newPlot(                        "53ea5369-f425-4caf-88e7-adfa228d8faf",                        [{"hovertemplate":"variable=wide_variable_0\u003cbr\u003eTicket classes=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"wide_variable_0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"wide_variable_0","orientation":"v","showlegend":true,"textposition":"auto","x":["economy","comfort","business"],"xaxis":"x","y":{"dtype":"i4","bdata":"roBbADeyCAAb8gsA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# по графику видим, что за все время эконом класс купили почти 6 миллионов раз, в то время, как комфорт и бизнес меньше 1 миллиона

# %%
describe_agg = lambda col: (
    F.count(col).alias(f"{col}_count"),
    F.min(col).alias(f"{col}_min"),
    F.max(col).alias(f"{col}_max"),
    F.avg(col).alias(f"{col}_avg"),
    F.mean(col).alias(f"{col}_mean"),
    F.stddev(col).alias(f"{col}_stddev"),
)

df \
    .withColumn('route', F.concat_ws(' -> ', F.concat_ws(' ', 'departure_country', 'departure_city'), F.concat_ws(' ', 'arrival_country', 'arrival_city'))) \
    .withColumn('total_tickets', F.col('target_economy') + F.col('target_comfort') + F.col('target_business')) \
    .withColumn('load_factor', F.col('total_tickets') / F.col('all_seats')) \
    .groupBy('route') \
    .agg(
        *describe_agg('target_economy'),
        *describe_agg('target_comfort'),
        *describe_agg('target_business'),
        F.avg('load_factor').alias('avg_load_factor'),
        F.max('load_factor').alias('max_load_factor'),
        F.min('load_factor').alias('min_load_factor')
    ) \
    .show()
# Out:
# +--------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+---------------------+-------------------+-------------------+-------------------+--------------------+----------------------+-------------------+------------------+--------------------+
# |               route|target_economy_count|target_economy_min|target_economy_max|target_economy_avg|target_economy_mean|target_economy_stddev|target_comfort_count|target_comfort_min|target_comfort_max|target_comfort_avg|target_comfort_mean|target_comfort_stddev|target_business_count|target_business_min|target_business_max|target_business_avg|target_business_mean|target_business_stddev|    avg_load_factor|   max_load_factor|     min_load_factor|
# +--------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+---------------------+-------------------+-------------------+-------------------+--------------------+----------------------+-------------------+------------------+--------------------+
# |Russia Saint Pete...|                 488|                 4|               326|           186.125|            186.125|     98.9752564332973|                 488|                 0|                48|21.493852459016395| 21.493852459016395|   16.618436952064023|                  488|                  0|                 48|  24.42827868852459|   24.42827868852459|    13.591388878666004| 0.7332709390658549|               1.0|0.012376237623762377|
# |Italy Rome -> Ita...|                 400|                 1|               326|          301.1025|           301.1025|     81.7889698107683|                 400|                 0|                48|            44.345|             44.345|   11.974951928263033|                  400|                  0|                 30|             27.745|              27.745|     7.509724689512973|  0.923743811881188|               1.0|0.002475247524752...|
# |United States Den...|                 118|                31|               326|169.01694915254237| 169.01694915254237|    79.49498538728017|                 118|                 0|                48| 8.542372881355933|  8.542372881355933|   16.198894162846035|                  118|                  4|                 48| 26.923728813559322|  26.923728813559322|    13.115630904051068|  0.853127444589309|               1.0|             0.21875|
# |Russia Moscow -> ...|                 194|                 1|               224|104.16494845360825| 104.16494845360825|    60.34369272815401|                 194|                 0|                28| 7.850515463917525|  7.850515463917525|    9.251428946749494|                  194|                  0|                 48|  16.15979381443299|   16.15979381443299|    16.083017528032734| 0.9183311855670103|               1.0|             0.00625|
# |Canada Toronto ->...|                 196|                 0|               326| 296.2755102040816|  296.2755102040816|    90.53128436323163|                 196|                 0|                48| 43.63775510204081|  43.63775510204081|   13.233074455695238|                  196|                  0|                 30|  27.23469387755102|   27.23469387755102|     8.430471009633449| 0.9087820771873106|               1.0|0.002475247524752...|
# |France Paris -> A...|                 118|                 4|               287|123.33898305084746| 123.33898305084746|    68.90377538426206|                 118|                 0|                45|5.8559322033898304| 5.8559322033898304|   11.359152658696399|                  118|                  0|                 44| 15.423728813559322|  15.423728813559322|     9.883428917824652|  0.499213027805388|               1.0|0.015384615384615385|
# |United States Mia...|                  17|                72|               224|107.76470588235294| 107.76470588235294|    66.46007204683568|                  17|                 0|                28| 6.588235294117647|  6.588235294117647|   12.242644850732887|                   17|                  6|                 29| 11.411764705882353|  11.411764705882353|    10.056458270244873|                1.0|               1.0|                 1.0|
# |Canada Montreal -...|                 208|                 0|               326|270.69711538461536| 270.69711538461536|    92.65681102498594|                 208|                 0|                48| 39.98076923076923|  39.98076923076923|   13.659051090764377|                  208|                  0|                 30|            24.9375|             24.9375|     8.748274502053821| 0.8307311500380806|               1.0|0.002475247524752...|
# |India Delhi -> In...|                  52|                43|               224|123.01923076923077| 123.01923076923077|   62.522620340950546|                  52|                 0|                28| 6.538461538461538|  6.538461538461538|    11.88253214326587|                   52|                  4|                 29|  16.76923076923077|   16.76923076923077|    11.387325917595602| 0.9842595127292637|               1.0| 0.18149466192170818|
# |Finland Helsinki ...|                  44|                14|               326| 94.81818181818181|  94.81818181818181|    66.46008514550344|                  44|                 0|                48|6.2272727272727275| 6.2272727272727275|   11.325755042059107|                   44|                  0|                 30|  9.545454545454545|   9.545454545454545|      6.90956379821525|0.48950129387938796|               1.0| 0.06930693069306931|
# |China Guangzhou -...|                 174|                 9|               188|155.72988505747125| 155.72988505747125|   23.779855539226485|                 174|                 0|                21| 6.396551724137931|  6.396551724137931|    9.692866673035372|                  174|                  1|                 48|  27.45402298850575|   27.45402298850575|    14.307347274535227| 0.9946120689655172|               1.0|              0.0625|
# |Russia Ufa -> Rus...|                  33|                10|               188| 79.72727272727273|  79.72727272727273|    45.49263177103019|                  33|                 0|                21| 8.636363636363637|  8.636363636363637|    5.909833869377071|                   33|                  1|                 48| 14.454545454545455|  14.454545454545455|    12.275715124512374| 0.8667632478471163|               1.0| 0.04669260700389105|
# |Sweden Stockholm ...|                 127|                 1|               281| 71.43307086614173|  71.43307086614173|   57.262496459833095|                 127|                 0|                21| 1.204724409448819|  1.204724409448819|    3.725371149459453|                  127|                  0|                 48| 10.976377952755906|  10.976377952755906|    11.096592188830963|0.48856370360976875|               1.0|0.006024096385542169|
# |China Guangzhou -...|                   9|                31|                52|44.888888888888886| 44.888888888888886|     8.08462189042327|                   9|                 7|                12|10.444444444444445| 10.444444444444445|    2.068278940998476|                    9|                  1|                  6|  4.777777777777778|   4.777777777777778|    1.7159383568311668| 0.8587301587301588|               1.0|  0.5571428571428572|
# |Sweden Stockholm ...|                  57|               138|               144|140.73684210526315| 140.73684210526315|   3.0150000935173744|                  57|                 0|                 0|               0.0|                0.0|                  0.0|                   57|                 16|                 28| 22.526315789473685|  22.526315789473685|     6.030000187034748|                1.0|               1.0|                 1.0|
# |Canada Edmonton -...|                  21|                 6|                72| 48.38095238095238|  48.38095238095238|   19.153266537267708|                  21|                 0|                12| 5.142857142857143|  5.142857142857143|    6.085110634045319|                   21|                  0|                  6|  4.619047619047619|   4.619047619047619|     2.201730920802778| 0.7893772893772893|               1.0| 0.08974358974358974|
# |Czech Republic Pr...|                  11|                 2|               142| 33.63636363636363|  33.63636363636363|    39.82027806852365|                  11|                 0|                11|3.1818181818181817| 3.1818181818181817|    3.970344615223767|                   11|                  1|                 37|  7.545454545454546|   7.545454545454546|    10.558064560928166|0.17262115316590027|0.7392996108949417|0.011673151750972763|
# |Japan Fukuoka -> ...|                  14|                16|                52|36.785714285714285| 36.785714285714285|   16.296193852121853|                  14|                 0|                12|               6.5|                6.5|   5.9839528998557725|                   14|                  0|                  6|  3.857142857142857|   3.857142857142857|    2.3487195482823227| 0.6597592883307167|               1.0| 0.20512820512820512|
# |China Hangzhou ->...|                  39|                 3|               224|105.92307692307692| 105.92307692307692|    70.50098342553535|                  39|                 0|                28| 8.051282051282051|  8.051282051282051|    9.880732760885591|                   39|                  0|                 29| 13.205128205128204|  13.205128205128204|     8.682042832553224| 0.5850898804635459|               1.0|0.010676156583629894|
# |United Kingdom Lo...|                  25|                18|               188|              82.8|               82.8|    48.57296916324277|                  25|                 0|                21|              6.96|               6.96|    8.157205403813245|                   25|                  3|                 48|               12.6|                12.6|      15.7797338380595| 0.9754285714285714|               1.0| 0.38571428571428573|
# +--------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+--------------------+------------------+------------------+------------------+-------------------+---------------------+---------------------+-------------------+-------------------+-------------------+--------------------+----------------------+-------------------+------------------+--------------------+
# only showing top 20 rows

# %%
overbooking_df = df.filter(
    (F.col("target_economy") > F.col("economy")) |
    (F.col("target_comfort") > F.col("comfort")) |
    (F.col("target_business") > F.col("business"))
).count()

print(f"Overbooking flights: {overbooking_df}")
# Out:
# Overbooking flights: 0

# %% [markdown]
# По этим данным можно сказать, что количество мест зависит от типа самолета и его вместительности и маршрута <br>
# в данной таблице добавил колонку загрузки самолета для оценки относительно маршрута <br>
# теперь надо сделать то же самое но для времени года для проверки сезонности. Возьму для группировки месяц вылета, так как группировать для каждого дня месяца может быть очень тяжело, так же для данной группы может быть мало данных, а в группировке по году будет слишком большое количество данных для выделения какой-нибудь закономерности

# %%
df \
    .withColumn('total_tickets', F.col('target_economy') + F.col('target_comfort') + F.col('target_business')) \
    .withColumn('load_factor', F.col('total_tickets') / F.col('all_seats')) \
    .groupBy('departure_year', 'departure_month') \
    .agg(
        F.count('flight_id').alias('flights'),
        F.avg('load_factor').alias('avg_load_factor'),
        F.max('load_factor').alias('max_load_factor'),
        F.min('load_factor').alias('min_load_factor')
    ) \
    .orderBy('departure_year', 'departure_month') \
    .show()
# Out:
# +--------------+---------------+-------+------------------+---------------+--------------------+
# |departure_year|departure_month|flights|   avg_load_factor|max_load_factor|     min_load_factor|
# +--------------+---------------+-------+------------------+---------------+--------------------+
# |          2025|             10|   5542|0.8586933944875607|            1.0|0.011673151750972763|
# |          2025|             11|   5445| 0.890954627414435|            1.0|0.012048192771084338|
# |          2025|             12|   5509|0.8821477373278291|            1.0|              0.0125|
# |          2026|              1|   5496|0.8406863340977349|            1.0|0.003891050583657...|
# |          2026|              2|   4871|0.8615856047292241|            1.0|0.007782101167315175|
# |          2026|              3|   5258|0.6850023788729855|            1.0|0.002475247524752...|
# |          2026|              4|   4431|0.4730422399822595|            1.0|0.002475247524752...|
# +--------------+---------------+-------+------------------+---------------+--------------------+

# %% [markdown]
# По таблице видно, что это данные непрерывны в течении 7 месяцев, начиная с октября и заканчивая апрелем. Явным аутсайдером является апрель, средняя загрузка самолета меньше половины и количество полетов в этот месяц так же меньше, чем в другие. Так же в марте загрузка самолетов меньше, чем раньше, но не столь критично как в апреле. <br>
# Значит существует зависимость полетов и времени года

# %%
indexer = StringIndexer(inputCol='airplane_model', outputCol='airplane_model_index')
df = indexer.fit(df).transform(df)
noncat_features = [feature.name for feature in df.schema if not isinstance(feature.dataType, StringType) and feature.name != 'flight_id']

assembler = VectorAssembler(inputCols=noncat_features, outputCol='corr_features')
df_vector = assembler.transform(df)
matrix = Correlation.corr(df_vector, 'corr_features').head()
dense_matrix = np.round(matrix.asDict()['pearson(corr_features)'].toArray(), 3)

# %%
fig = px.imshow(
    dense_matrix,
    x=noncat_features,
    y=noncat_features,
    color_continuous_scale='RdBu',
    range_color=(-1, 1),
    aspect='auto',
    title='Correlation Matrix',
)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="d7e3cf5a-993b-4032-837f-5ab736108a3e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7e3cf5a-993b-4032-837f-5ab736108a3e")) {                    Plotly.newPlot(                        "d7e3cf5a-993b-4032-837f-5ab736108a3e",                        [{"coloraxis":"coloraxis","name":"0","x":["target_economy","target_comfort","target_business","departure_year","departure_month","departure_day","departure_day_of_week","is_weekend","departure_hour","departure_minute","duration_hours","duration_minutes","count_of_week_routes","airplane_range","airplane_speed","economy","comfort","business","all_seats","avg_book_lead_time","min_book_lead_time","max_book_lead_time","s2_book_lead_time","count_book_lead_time","distance","is_avg_book_lead_time_missing","is_min_book_lead_time_missing","is_max_book_lead_time_missing","is_s2_book_lead_time_missing","airplane_model_index"],"y":["target_economy","target_comfort","target_business","departure_year","departure_month","departure_day","departure_day_of_week","is_weekend","departure_hour","departure_minute","duration_hours","duration_minutes","count_of_week_routes","airplane_range","airplane_speed","economy","comfort","business","all_seats","avg_book_lead_time","min_book_lead_time","max_book_lead_time","s2_book_lead_time","count_book_lead_time","distance","is_avg_book_lead_time_missing","is_min_book_lead_time_missing","is_max_book_lead_time_missing","is_s2_book_lead_time_missing","airplane_model_index"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D956SYxCKzoPylcj8L1KOg\u002f2\u002fl+arx0w7+JQWDl0CK7Pzm0yHa+n7q\u002fObTIdr6fij\u002f6fmq8dJN4P\u002fyp8dJNYpC\u002fuB6F61G4nj\u002fjpZvEILDSv\u002fp+arx0k6g\u002fJQaBlUOL1D9g5dAi2\u002fniPxkEVg4tsuE\u002fwcqhRbbz5T9KDAIrhxbhP\u002fyp8dJNYtg\u002fw\u002fUoXI\u002fC5T\u002fJdr6fGi+tv\u002fT91HjpJrG\u002fTDeJQWDloD9KDAIrhxapP+58PzVeuuU\u002fSgwCK4cW0b\u002fZzvdT46Wrv9nO91Pjpau\u002f2c73U+Olq79CYOXQItu5vx+F61G4Ht2\u002feekmMQis6D8AAAAAAADwP30\u002fNV66Sdw\u002fi2zn+6nxsr\u002fpJjEIrByqPylcj8L1KKy\u002f+n5qvHSTeD\u002f6fmq8dJNoP5zEILByaJG\u002f7FG4HoXroT+8dJMYBFbOv9nO91Pjpas\u002fdZMYBFYOzT9kO99PjZfeP1TjpZvEIOA\u002ffT81XrpJ5D+wcmiR7XzrP3E9CtejcM0\u002fbxKDwMqh5T956SYxCKyMv5zEILByaJG\u002fWmQ730+Npz\u002f6fmq8dJOYPzvfT42XbuI\u002fiUFg5dAiy7+q8dJNYhCov6rx0k1iEKi\u002fqvHSTWIQqL+LbOf7qfGyvxKDwMqhRd6\u002fKVyPwvUo6D99PzVeukncPwAAAAAAAPA\u002fVOOlm8QgwL\u002fD9Shcj8K1P0Jg5dAi27m\u002fO99PjZdugj\u002f6fmq8dJNoPwAAAAAAAAAAAAAAAAAAAIC+nxov3STGv\u002fp+arx0k4g\u002f2\u002fl+arx0wz+F61G4HoXjP1YOLbKd7+M\u002f16NwPQrX2z\u002fNzMzMzMzMPxSuR+F6FOY\u002fw\u002fUoXI\u002fC3T+6SQwCK4emv5MYBFYOLbK\u002f+n5qvHSTqD8j2\u002fl+ary0P5zEILByaOE\u002fN4lBYOXQwr8IrBxaZDuvvwisHFpkO6+\u002fCKwcWmQ7r7+JQWDl0CK7v1K4HoXrUci\u002f2\u002fl+arx0w7+LbOf7qfGyv1TjpZvEIMC\u002fAAAAAAAA8D9eukkMAivvv3sUrkfheqS\u002f\u002fKnx0k1iUD8AAAAAAAAAgHsUrkfhepQ\u002f\u002fKnx0k1ikL+cxCCwcmiRP\u002fyp8dJNYlA\u002f\u002fKnx0k1iUD\u002f8qfHSTWKgP3npJjEIrJw\u002fO99PjZdukj+cxCCwcmiRP2q8dJMYBKY\u002fukkMAiuHlj+R7Xw\u002fNV7SPz81XrpJDNI\u002fYOXQItv5zj8K16NwPQqnv3sUrkfheqQ\u002fO99PjZdukj\u002f8qfHSTWKgv\u002fyp8dJNYqC\u002f\u002fKnx0k1ioL\u002fb+X5qvHSTv\u002fp+arx0k3i\u002fiUFg5dAiuz\u002fpJjEIrByqP8P1KFyPwrU\u002fXrpJDAIr778AAAAAAADwP1g5tMh2vp8\u002feekmMQisfL\u002f8qfHSTWJQv5zEILByaJG\u002fO99PjZdukj8bL90kBoGVv\u002fyp8dJNYmC\u002fexSuR+F6dL9MN4lBYOWgv3npJjEIrJy\u002f2\u002fl+arx0k7\u002f8qfHSTWKQvxsv3SQGgaW\u002fWmQ730+Nl7+F61G4HoXLvzVeukkMAsu\u002fukkMAiuHxr8rhxbZzvejP0w3iUFg5aC\u002fukkMAiuHlr+6SQwCK4eGP7pJDAIrh4Y\u002fukkMAiuHhj\u002f8qfHSTWJwPzvfT42XboI\u002fObTIdr6fur8pXI\u002fC9Sisv0Jg5dAi27m\u002fexSuR+F6pL9YObTIdr6fPwAAAAAAAPA\u002fO99PjZdugj\u002f8qfHSTWJgP3sUr ...

# %% [markdown]
# по данной матрице видно, что наши таргеты коррелируют с дистанцией, общим количество мест (лимит сверху) и количество уже забронированных билетов <br>
# так же из предыдущих расчетов мы выяснили, что время года, маршрут, модель самолета и соответственно дистанция коррелирует с количеством проданных билетов <br>
# уберем признаки, которые сильно коррелируют с другими, чтобы в будущем модель лучше искала зависимости

# %%
target = [
    'target_economy',
    'target_comfort',
    'target_business',
]

# оставим только те признаки, которые нам будут нужны для будущих моделей. Как линейных, так и нет
features = [
    # временные
    'departure_day',
    'departure_day_of_week',
    'departure_month',
    'is_weekend',
    'departure_hour',

    # физический смысл рейса
    'duration_hours',
    'count_of_week_routes',
    'airplane_range',
    'economy',
    'comfort',
    'business',

    # метрики бронирования за 30 дней
    'avg_book_lead_time',
    's2_book_lead_time',
    'count_book_lead_time',

    # метрики пропуска данных
    'is_avg_book_lead_time_missing'
]

cat_features = [
    'departure_city',
    'departure_country',
    'arrival_city',
    'arrival_country',
    'airplane_model'
]

# %%
final_columns = target + features + cat_features
final_columns
# Out:
# ['target_economy',
#  'target_comfort',
#  'target_business',
#  'departure_day',
#  'departure_day_of_week',
#  'departure_month',
#  'is_weekend',
#  'departure_hour',
#  'duration_hours',
#  'count_of_week_routes',
#  'airplane_range',
#  'economy',
#  'comfort',
#  'business',
#  'avg_book_lead_time',
#  's2_book_lead_time',
#  'count_book_lead_time',
#  'is_avg_book_lead_time_missing',
#  'departure_city',
#  'departure_country',
#  'arrival_city',
#  'arrival_country',
#  'airplane_model']

# %%
df = df.select(final_columns)
df.show(5)
# Out:
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |target_economy|target_comfort|target_business|departure_day|departure_day_of_week|departure_month|is_weekend|departure_hour|duration_hours|count_of_week_routes|airplane_range|economy|comfort|business|avg_book_lead_time|  s2_book_lead_time|count_book_lead_time|is_avg_book_lead_time_missing|  departure_city|departure_country|arrival_city|arrival_country|   airplane_model|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |           326|            48|             30|            1|                    3|             10|         0|             5|             1|                   7|         14600|    326|     48|      30|30.120028891673627|0.05985291147778805|                 133|                            0|           Paris|           France|        Nice|         France| Boeing 777-300ER|
# |           115|             0|             13|            1|                    3|             10|         0|             5|             7|                   1|          7000|    144|      0|      16|30.123078703703705|0.08308504678941933|                   2|                            0|         Beijing|            China|         Goa|          India| Boeing 737 MAX 7|
# |           144|             0|             16|            1|                    3|             10|         0|             7|             1|                   6|          7000|    144|      0|      16|30.177904128086418|0.09870410648688327|                  24|                            0|           Miami|    United States|   Charlotte|  United States| Boeing 737 MAX 7|
# |           281|             0|             44|            1|                    3|             10|         0|             8|             1|                   7|         16700|    281|      0|      44|30.152721522394486|0.09039887194550104|                  43|                            0|Saint Petersburg|           Russia|      Moscow|         Russia|Aerobus A350-1000|
# |           281|             0|             44|            1|                    3|             10|         0|            13|             1|                   6|         16700|    281|      0|      44|30.292628451554236|0.16560835852028494|                 112|                            0|         Orlando|    United States|     Atlanta|  United States|Aerobus A350-1000|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# only showing top 5 rows

# %%
eda_save_path = Path.cwd().parent / 'data' / 'cleaned_data'
eda_save_path.mkdir(parents=True, exist_ok=True)

df \
    .write \
    .mode('overwrite') \
    .parquet(str(eda_save_path))

# %%
df.count(), len(df.columns)
# Out:
# (36552, 23)

# %%
from pathlib import Path

import mlflow
import optuna
from mlflow.utils.autologging_utils import disable_autologging
from optuna import Trial
from pyspark.ml import Pipeline, PipelineModel
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, OneHotEncoder
from pyspark.ml.regression import LinearRegression
from pyspark.sql import SparkSession, DataFrame

from utility_data.utils import time_train_test_split, wape_metric

# %%
mlflow.set_tracking_uri('http://localhost:5000')
mlflow.set_experiment('PlaneCostPrediction')

spark = SparkSession \
    .builder \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memory", "1g") \
    .config("spark.sql.shuffle.partitions", "20") \
    .getOrCreate()

df_path = Path.cwd().parent / 'data' / 'cleaned_data'
df = spark.read.parquet(str(df_path))

all_features = df.columns
cat_features = [name for name, dtype in df.dtypes if dtype == 'string']

df.show(5)
# Out:
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |target_economy|target_comfort|target_business|departure_day|departure_day_of_week|departure_month|is_weekend|departure_hour|duration_hours|count_of_week_routes|airplane_range|economy|comfort|business|avg_book_lead_time|  s2_book_lead_time|count_book_lead_time|is_avg_book_lead_time_missing|  departure_city|departure_country|arrival_city|arrival_country|   airplane_model|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |           326|            48|             30|            1|                    3|             10|         0|             5|             1|                   7|         14600|    326|     48|      30|30.120028891673627|0.05985291147778805|                 133|                            0|           Paris|           France|        Nice|         France| Boeing 777-300ER|
# |           115|             0|             13|            1|                    3|             10|         0|             5|             7|                   1|          7000|    144|      0|      16|30.123078703703705|0.08308504678941933|                   2|                            0|         Beijing|            China|         Goa|          India| Boeing 737 MAX 7|
# |           144|             0|             16|            1|                    3|             10|         0|             7|             1|                   6|          7000|    144|      0|      16|30.177904128086418|0.09870410648688327|                  24|                            0|           Miami|    United States|   Charlotte|  United States| Boeing 737 MAX 7|
# |           281|             0|             44|            1|                    3|             10|         0|             8|             1|                   7|         16700|    281|      0|      44|30.152721522394486|0.09039887194550104|                  43|                            0|Saint Petersburg|           Russia|      Moscow|         Russia|Aerobus A350-1000|
# |           281|             0|             44|            1|                    3|             10|         0|            13|             1|                   6|         16700|    281|      0|      44|30.292628451554236|0.16560835852028494|                 112|                            0|         Orlando|    United States|     Atlanta|  United States|Aerobus A350-1000|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# only showing top 5 rows

# %% [markdown]
# Использовать StringIndexer для замены не численных признаков в линейной регрессии является не плохой практикой, так как модель может решить, что какая-то категория лучше другой, потому что там больше число.
# Воспользуемся OHE, для заменя категориальных признаков

# %%
index_cols, ohe_cols = map(list, zip(*[(f'{col}_index', f'{col}_ohe') for col in cat_features]))
exclude_cols = index_cols + cat_features + ['target_economy', 'target_comfort', 'target_business']
features = [col for col in all_features if col not in exclude_cols] + ohe_cols

indexer = StringIndexer(inputCols=cat_features, outputCols=index_cols, handleInvalid='keep')
ohe = OneHotEncoder(inputCols=index_cols, outputCols=ohe_cols, handleInvalid='keep')
assembler = VectorAssembler(inputCols=features, outputCol='features', handleInvalid='keep')

models = {
    'economy': {'labelCol': 'target_economy', 'featuresCol': 'features', 'predictionCol': 'prediction_economy'},
    'comfort': {'labelCol': 'target_comfort', 'featuresCol': 'features', 'predictionCol': 'prediction_comfort'},
    'business': {'labelCol': 'target_business', 'featuresCol': 'features', 'predictionCol': 'prediction_business'},
}

mlflow.pyspark.ml.autolog(log_models=False, log_datasets=False)

# %%
def objective(trial: Trial, model_name: str, model_cols: dict[str, str], train_data: DataFrame, valid_data: DataFrame):
    params = {
        'regParam': trial.suggest_float('regParam', 1e-9, 1, log=True),
        'elasticNetParam': trial.suggest_float('elasticNetParam', 1e-9, 1, log=True),
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),
        'maxIter': trial.suggest_int('maxIter', 10, 1000),
    }

    with disable_autologging():
        optuna_model = LinearRegression(featuresCol=model_cols['featuresCol'], labelCol=model_cols['labelCol'], predictionCol=model_cols['predictionCol'], **params)
        optuna_model = optuna_model.fit(train_data)
    val_preds = optuna_model.transform(valid_data)

    val_wape = wape_metric(val_preds, label_col=model_cols['labelCol'], prediction_col=model_cols['predictionCol'])
    val_rmse = RegressionEvaluator(predictionCol=model_cols['predictionCol'], labelCol=model_cols['labelCol']).evaluate(val_preds)

    mlflow.log_metric(f'{model_name}_val_rmse', val_rmse, step=trial.number)
    mlflow.log_metric(f'{model_name}_val_wape', val_wape, step=trial.number)

    return val_wape

# %%
with mlflow.start_run(run_name='improve_linear_regression', tags={'mlflow.user': 'Alexander'}) as run:
    train, test, train_meta = time_train_test_split(df, 0.25)
    valid, test, valid_meta = time_train_test_split(test, 0.5)

    mlflow.log_params({
        "all_days": train_meta["all_days"],
        "train_days_count": train_meta["train_size"],
        "valid_days_count": valid_meta["train_size"],
        "test_days_count": valid_meta["all_days"] - valid_meta["train_size"]
    })

    print(f"All days = {train_meta['all_days']}\n"
          f"Train days size = {train_meta['train_size']}\n"
          f"Valid days size = {valid_meta['train_size']}\n"
          f"Test days size = {valid_meta['all_days'] - valid_meta['train_size']}")
    print(f"All rows = {df.count()}\n"
          f"Train rows = {train.count()}\n"
          f"Valid rows = {valid.count()}\n"
          f"Test rows = {test.count()}")

    features_pipeline = Pipeline(stages=[indexer, ohe, assembler])
    features_pipeline = features_pipeline.fit(train)
    train_piped = features_pipeline.transform(train).cache()
    valid_piped = features_pipeline.transform(valid).cache()

    models_pipeline_stages = []
    for cur_model_name, cur_model_cols in models.items():
        study = optuna.create_study(study_name=f'Optuna_{cur_model_name}_study', direction='minimize')
        study.optimize(lambda trial: objective(trial, cur_model_name, cur_model_cols, train_piped, valid_piped), n_trials=20, show_progress_bar=True)

        print(f"--> {cur_model_name} val WAPE = {study.best_value * 100:.2f}%")

        with disable_autologging():
            model = LinearRegression(featuresCol=cur_model_cols['featuresCol'], labelCol=cur_model_cols['labelCol'], predictionCol=cur_model_cols['predictionCol'], **study.best_params).fit(train_piped)
            models_pipeline_stages.append(model)

    train_piped.unpersist()
    valid_piped.unpersist()

    model_pipeline = PipelineModel(stages=[*features_pipeline.stages, *models_pipeline_stages])
    mean_rmse, mean_wape = 0, 0
    preds = model_pipeline.transform(test).cache()

    for model_name, model_cols in models.items():
        rmse = RegressionEvaluator(predictionCol=model_cols['predictionCol'], labelCol=model_cols['labelCol']).evaluate(preds)
        wape = wape_metric(preds, label_col=model_cols['labelCol'], prediction_col=model_cols['predictionCol'])
        print(f'{model_name} predictions\nRMSE = {rmse:.4f}\nWAPE = {wape * 100:.4f}%\n')

        mean_rmse += rmse
        mean_wape += wape

        mlflow.log_metric(f'{model_name} RMSE', rmse)
        mlflow.log_metric(f'{model_name} WAPE', wape)

    mean_rmse /= len(models)
    mean_wape /= len(models)

    print(f'Mean RMSE = {mean_rmse:.4f}\nMean WAPE = {mean_wape * 100:.4f}%\n')

    mlflow.log_metric('Mean RMSE', mean_rmse)
    mlflow.log_metric('Mean WAPE', mean_wape)
    mlflow.spark.log_model(model_pipeline, 'improve_linear_regression')
# Out:
# All days = 211
# Train days size = 158
# Valid days size = 26
# Test days size = 27
# All rows = 36552
# Train rows = 27048
# Valid rows = 4706
# Test rows = 4798
# [I 2026-07-11 20:03:00,657] A new study created in memory with name: Optuna_economy_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-11 20:03:06,816] Trial 0 finished with value: 0.19911129815499606 and parameters: {'regParam': 0.00037969001765761134, 'elasticNetParam': 0.007068300782496917, 'tol': 0.00023047605323381356, 'maxIter': 602}. Best is trial 0 with value: 0.19911129815499606.
# [I 2026-07-11 20:03:07,866] Trial 1 finished with value: 0.19911106860693933 and parameters: {'regParam': 0.0006290718603801926, 'elasticNetParam': 0.0009585500383931798, 'tol': 2.0278361466978167e-05, 'maxIter': 806}. Best is trial 1 with value: 0.19911106860693933.
# [I 2026-07-11 20:03:08,940] Trial 2 finished with value: 0.19911439246948964 and parameters: {'regParam': 5.6783725305920927e-08, 'elasticNetParam': 1.3640811399908183e-05, 'tol': 0.0006162760680548464, 'maxIter': 256}. Best is trial 1 with value: 0.19911106860693933.
# [I 2026-07-11 20:03:09,902] Trial 3 finished with value: 0.19911236061869828 and parameters: {'regParam': 1.4478099764685543e-09, 'elasticNetParam': 0.02090930677243411, 'tol': 5.8672413487281134e-05, 'maxIter': 807}. Best is trial 1 with value: 0.19911106860693933.
# [I 2026-07-11 20:03:10,871] Trial 4 finished with value: 0.19909707927627737 and parameters: {'regParam': 0.0048556582094362, 'elasticNetParam': 3.4833258462147094e-06, 'tol': 1.408473227780768e-06, 'maxIter': 735}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:11,794] Trial 5 finished with value: 0.1991136049581974 and parameters: {'regParam': 3.1882134870231263e-06, 'elasticNetParam': 1.1471793476444352e-09, 'tol': 2.236952152006064e-06, 'maxIter': 284}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:12,765] Trial 6 finished with value: 0.1991094487652822 and parameters: {'regParam': 0.0026840967850713746, 'elasticNetParam': 1.7069788101125992e-06, 'tol': 0.00029568477044551874, 'maxIter': 850}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:13,729] Trial 7 finished with value: 0.1991016337375553 and parameters: {'regParam': 8.385854340079761e-08, 'elasticNetParam': 9.17912963121153e-05, 'tol': 0.03161749755948149, 'maxIter': 859}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:14,618] Trial 8 finished with value: 0.19925863365904423 and parameters: {'regParam': 0.014607066756173574, 'elasticNetParam': 0.00012256517726523511, 'tol': 0.025043183936497692, 'maxIter': 705}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:15,386] Trial 9 finished with value: 0.1990988304665129 and parameters: {'regParam': 0.005287227187428838, 'elasticNetParam': 5.611682171674291e-07, 'tol': 1.3578110201679962e-06, 'maxIter': 450}. Best is trial 4 with value: 0.19909707927627737.
# [I 2026-07-11 20:03:15,975] Trial 10 finished with value: 0.19543907745651604 and parameters: {'regParam': 0.415142040606705, 'elasticNetParam': 0.6223165194502359, 'tol': 0.0035363568859623712, 'maxIter': 12}. Best is trial 10 with value: 0.19543907745651604.
# [I 2026-07-11 20:03:16,604] Trial 11 finished with value: 0.19341248349908333 and parameters: {'regParam': 0.9539260162806751, 'elasticNetParam': 0.8989498722000248, 'tol': 0.003342416328158476, 'maxIter': 44}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:17,507] Trial 12 finished with value: 0.19452534958379128 and parameters: {'regParam': 0.8270920455020344, 'elasticNetParam': 0.36541633358123926, 'tol': 0.0037756072093322476, 'maxIter': 50}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:18,309] Trial 13 finished with value: 0.19550678428005544 and parameters: {'regParam': 0.9039320213638748, 'elasticNetParam': 0.1836428893060273, 'tol': 0.0046717605362505766, 'maxIter': 14}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:19,180] Trial 14 finished with value: 0.1962434715077442 and parameters: {'regParam': 0.30188511457314926, 'elasticNetParam': 0.7467889380151345, 'tol': 0.0037568285934439383, 'maxIter': 161}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:20,001] Trial 15 finished with value: 0.1980392354668712 and parameters: {'regParam': 0.038594319453732005, 'elasticNetParam': 0.02422373787349093, 'tol': 0.07376621813294061, 'maxIter': 152}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:20,855] Trial 16 finished with value: 0.19872913265311454 and parameters: {'regParam': 0.10719353977648441, 'elasticNetParam': 0.0695241616875181, 'tol': 0.0013061958346928064, 'maxIter': 397}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:21,666] Trial 17 finished with value: 0.19920943360144958 and parameters: {'regParam': 9.546240771402557e-05, 'elasticNetParam': 0.0024996260912824894, 'tol': 0.011419542358493507, 'maxIter': 129}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:22,457] Trial 18 finished with value: 0.19824045427502046 and parameters: {'regParam': 0.07805291932452055, 'elasticNetParam': 0.8094694515259746, 'tol': 0.0011596749694725785, 'maxIter': 982}. Best is trial 11 with value: 0.19341248349908333.
# [I 2026-07-11 20:03:23,317] Trial 19 finished with value: 0.19911591467039652 and parameters: {'regParam': 1.0519320608145032e-05, 'elasticNetParam': 0.07647663654599096, 'tol': 6.0297059315203305e-05, 'maxIter': 257}. Best is trial 11 with value: 0.19341248349908333.
# --> economy val WAPE = 19.34%
# [I 2026-07-11 20:03:23,610] A new study created in memory with name: Optuna_comfort_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-11 20:03:24,204] Trial 0 finished with value: 0.25349483354981533 and parameters: {'regParam': 0.0007472239852449933, 'elasticNetParam': 0.0044744396724529425, 'tol': 0.05661787818266331, 'maxIter': 811}. Best is trial 0 with value: 0.25349483354981533.
# [I 2026-07-11 20:03:24,948] Trial 1 finished with value: 0.25325607869466 and parameters: {'regParam': 0.14977673559658683, 'elasticNetParam': 0.0014634447359065672, 'tol': 0.004148867402965666, 'maxIter': 580}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:25,784] Trial 2 finished with value: 0.2540955865707905 and parameters: {'regParam': 1.052335522775345e-09, 'elasticNetParam': 0.0006097551716414381, 'tol': 0.025997685142578112, 'maxIter': 112}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:26,601] Trial 3 finished with value: 0.25436437878935286 and parameters: {'regParam': 6.812982560078042e-05, 'elasticNetParam': 6.542819134579236e-08, 'tol': 0.005526649958692929, 'maxIter': 916}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:27,386] Trial 4 finished with value: 0.254279425660578 and parameters: {'regParam': 1.095977890470798e-07, 'elasticNetParam': 0.0001929856936192125, 'tol': 0.001904735446339529, 'maxIter': 293}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:28,145] Trial 5 finished with value: 0.2542940862251039 and parameters: {'regParam': 8.189584077040642e-09, 'elasticNetParam': 1.006763815433662e-05, 'tol': 4.256241075518919e-06, 'maxIter': 718}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:28,965] Trial 6 finished with value: 0.25428634676539447 and parameters: {'regParam': 1.1120056832205433e-07, 'elasticNetParam': 4.7746512321394814e-05, 'tol': 0.0007292231668605175, 'maxIter': 735}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:29,679] Trial 7 finished with value: 0.25427707665125865 and parameters: {'regParam': 0.00016486275219607238, 'elasticNetParam': 0.547618692935533, 'tol': 5.599035674351835e-05, 'maxIter': 762}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:30,210] Trial 8 finished with value: 0.254289531609385 and parameters: {'regParam': 2.2867926645949755e-09, 'elasticNetParam': 0.0009368021421480761, 'tol': 8.5864524514583e-05, 'maxIter': 750}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:30,727] Trial 9 finished with value: 0.254309251712836 and parameters: {'regParam': 0.00010451966600425058, 'elasticNetParam': 0.04527554884177537, 'tol': 8.423671498962252e-05, 'maxIter': 208}. Best is trial 1 with value: 0.25325607869466.
# [I 2026-07-11 20:03:31,210] Trial 10 finished with value: 0.2522061845748844 and parameters: {'regParam': 0.42028768860860827, 'elasticNetParam': 1.2729779173881476e-09, 'tol': 1.4921291018611795e-06, 'maxIter': 481}. Best is trial 10 with value: 0.2522061845748844.
# [I 2026-07-11 20:03:31,709] Trial 11 finished with value: 0.2515653108445428 and parameters: {'regParam': 0.6874711813348788, 'elasticNetParam': 1.2212795516276185e-09, 'tol': 2.1244125722203597e-06, 'maxIter': 483}. Best is trial 11 with value: 0.2515653108445428.
# [I 2026-07-11 20:03:32,202] Trial 12 finished with value: 0.251564988285673 and parameters: {'regParam': 0.7122955034837073, 'elasticNetParam': 2.0135719205365755e-09, 'tol': 1.104775185613234e-06, 'maxIter': 479}. Best is trial 12 with value: 0.251564988285673.
# [I 2026-07-11 20:03:32,677] Trial 13 finished with value: 0.2541865714771626 and parameters: {'regParam': 0.018029718398096722, 'elasticNetParam': 1.1444556374136004e-09, 'tol': 7.3034898428694385e-06, 'maxIter': 454}. Best is trial 12 with value: 0.251564988285673.
# [I 2026-07-11 20:03:33,147] Trial 14 finished with value: 0.2542311032458584 and parameters: {'regParam': 0.009724699835011143, 'elasticNetParam': 6.385901175812522e-08, 'tol': 1.1690680249412279e-06, 'maxIter': 370}. Best is trial 12 with value: 0.251564988285673.
# [I 2026-07-11 20:03:33,640] Trial 15 finished with value: 0.2513929698954993 and parameters: {'regParam': 0.9337706621555205, 'elasticNetParam': 7.598802815384792e-08, 'tol': 9.193855863339628e-06, 'maxIter': 593}. Best is trial 15 with value: 0.2513929698954993.
# [I 2026-07-11 20:03:34,128] Trial 16 finished with value: 0.25412673790056917 and parameters: {'regParam': 0.023800407850748287, 'elasticNetParam': 1.770510969721145e-07, 'tol': 1.1635969886411873e-05, 'maxIter': 624}. Best is trial 15 with value: 0.2513929698954993.
# [I 2026-07-11 20:03:34,638] Trial 17 finished with value: 0.254370551756616 and parameters: {'regParam': 0.002837538990973046, 'elasticNetParam': 7.535455858991021e-07, 'tol': 2.9944175759949993e-05, 'maxIter': 20}. Best is trial 15 with value: 0.2513929698954993.
# [I 2026-07-11 20:03:35,147] Trial 18 finished with value: 0.25138204234269607 and parameters: {'regParam': 0.8985390029302368, 'elasticNetParam': 1.5044237196387267e-08, 'tol': 1.4086798623310483e-05, 'maxIter': 605}. Best is trial 18 with value: 0.25138204234269607.
# [I 2026-07-11 20:03:35,633] Trial 19 finished with value: 0.2538823576465516 and parameters: {'regParam': 0.06253202634486414, 'elasticNetParam': 1.9649798628486866e-06, 'tol': 0.0001694871073223137, 'maxIter': 977}. Best is trial 18 with value: 0.25138204234269607.
# --> comfort val WAPE = 25.14%
# [I 2026-07-11 20:03:35,877] A new study created in memory with name: Optuna_business_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-11 20:03:36,385] Trial 0 finished with value: 0.230388152813962 and parameters: {'regParam': 0.0021314352657816216, 'elasticNetParam': 0.11195657356207457, 'tol': 0.00010012999266627729, 'maxIter': 311}. Best is trial 0 with value: 0.230388152813962.
# [I 2026-07-11 20:03:36,889] Trial 1 finished with value: 0.23041129373930055 and parameters: {'regParam': 2.2702507272031367e-08, 'elasticNetParam': 6.384887268590889e-07, 'tol': 2.508691018395434e-06, 'maxIter': 143}. Best is trial 0 with value: 0.230388152813962.
# [I 2026-07-11 20:03:37,389] Trial 2 finished with value: 0.2304081738292861 and parameters: {'regParam': 5.282813391159417e-08, 'elasticNetParam': 5.830817297660359e-08, 'tol': 0.00016278422442550863, 'maxIter': 613}. Best is trial 0 with value: 0.230388152813962.
# [I 2026-07-11 20:03:37,862] Trial 3 finished with value: 0.22494014438745233 and parameters: {'regParam': 0.6084551319856292, 'elasticNetParam': 7.370329005727106e-06, 'tol': 0.0017767603051282678, 'maxIter': 927}. Best is trial 3 with value: 0.22494014438745233.
# [I 2026-07-11 20:03:38,347] Trial 4 finished with value: 0.23033110675524324 and parameters: {'regParam': 0.006227148855924398, 'elasticNetParam': 4.0039807232111687e-07, 'tol': 1.0581132605495114e-05, 'maxIter': 764}. Best is trial 3 with value: 0.22494014438745233.
# [I 2026-07-11 20:03:38,830] Trial 5 finished with value: 0.23041065861234689 and parameters: {'regParam': 0.00020234109982160905, 'elasticNetParam': 0.2930180161411401, 'tol': 4.798879598987616e-05, 'maxIter': 862}. Best is trial 3 with value: 0.22494014438745233.
# [I 2026-07-11 20:03:39,320] Trial 6 finished with value: 0.22383598394950996 and parameters: {'regParam': 0.8828000990452792, 'elasticNetParam': 0.0009227415905613262, 'tol': 0.028672815481782316, 'maxIter': 251}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:39,771] Trial 7 finished with value: 0.23039968154657633 and parameters: {'regParam': 5.455940529769238e-07, 'elasticNetParam': 1.0136856449890839e-09, 'tol': 0.0019202861094348616, 'maxIter': 686}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:40,259] Trial 8 finished with value: 0.230412273033946 and parameters: {'regParam': 4.652304313138666e-06, 'elasticNetParam': 0.0002805578064750143, 'tol': 0.000259803511999652, 'maxIter': 735}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:40,738] Trial 9 finished with value: 0.23041541294262063 and parameters: {'regParam': 4.261273583709384e-07, 'elasticNetParam': 0.0003045834874186271, 'tol': 5.1290489142499405e-06, 'maxIter': 953}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:41,198] Trial 10 finished with value: 0.2286056187700386 and parameters: {'regParam': 2.1752081875697897e-09, 'elasticNetParam': 0.002667569137241313, 'tol': 0.08595870402778866, 'maxIter': 460}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:41,653] Trial 11 finished with value: 0.2255888682462561 and parameters: {'regParam': 0.5042480634297926, 'elasticNetParam': 6.766054714465822e-05, 'tol': 0.01958914139982164, 'maxIter': 66}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:42,114] Trial 12 finished with value: 0.2240050767513223 and parameters: {'regParam': 0.7960926103672703, 'elasticNetParam': 1.0648345527311177e-05, 'tol': 0.0037522137692289174, 'maxIter': 415}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:42,591] Trial 13 finished with value: 0.22995062391026266 and parameters: {'regParam': 0.0363771224010714, 'elasticNetParam': 0.013458295925223596, 'tol': 0.004099854386710822, 'maxIter': 300}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:43,070] Trial 14 finished with value: 0.22932667527232842 and parameters: {'regParam': 0.06941455542477125, 'elasticNetParam': 1.075496583990206e-05, 'tol': 0.019237982030278083, 'maxIter': 441}. Best is trial 6 with value: 0.22383598394950996.
# [I 2026-07-11 20:03:43,743] Trial 15 finished with value: 0.2222282516892971 and parameters: {'regParam': 0.9281075523806362, 'elasticNetParam': 0.004570389127418063, 'tol': 0.06726390536634702, 'maxIter': 245}. Best is trial 15 with value: 0.2222282516892971.
# [I 2026-07-11 20:03:44,472] Trial 16 finished with value: 0.2273285841242123 and parameters: {'regParam': 0.00044712713878982026, 'elasticNetParam': 0.005767308295690022, 'tol': 0.0987888168307334, 'maxIter': 192}. Best is trial 15 with value: 0.2222282516892971.
# [I 2026-07-11 20:03:45,027] Trial 17 finished with value: 0.2297570733708844 and parameters: {'regParam': 0.039039384927218986, 'elasticNetParam': 0.06381486558483712, 'tol': 0.018631492419830427, 'maxIter': 27}. Best is trial 15 with value: 0.2222282516892971.
# [I 2026-07-11 20:03:45,768] Trial 18 finished with value: 0.23018872909419347 and parameters: {'regParam': 4.658724137421005e-05, 'elasticNetParam': 0.969648864932352, 'tol': 0.03337515799380151, 'maxIter': 279}. Best is trial 15 with value: 0.2222282516892971.
# [I 2026-07-11 20:03:46,561] Trial 19 finished with value: 0.23020529580967142 and parameters: {'regParam': 0.009359364964592273, 'elasticNetParam': 0.001141904220974657, 'tol': 0.0069810560055715365, 'maxIter': 170}. Best is trial 15 with value: 0.2222282516892971.
# --> business val WAPE = 22.22%
# economy predictions
# RMSE = 50.6249
# WAPE = 19.9764%
#
# comfort predictions
# RMSE = 6.7370
# WAPE = 27.7270%
#
# business predictions
# RMSE = 6.8361
# WAPE = 22.5688%
#
# Mean RMSE = 21.3993
# Mean WAPE = 23.4241%
# 2026/07/11 20:04:09 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\ALEXAN~1\AppData\Local\Temp\tmpr3k7l982\model, flavor: spark). Fall back to return ['pyspark==4.1.2']. Set logging level to DEBUG to see the full traceback.
# 2026/07/11 20:04:09 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run improve_linear_regression at: http://localhost:5000/#/experiments/1/runs/dc85779421c040b09fdba2b21ebc09cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Модель почти не улучшила свои показатели после подбора гиперпараметров по сравнению с baseline'ом, это значит, что она достигла своего предела и надо переходить к другим методам машинного обучения

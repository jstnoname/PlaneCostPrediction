# %%
import mlflow
import optuna
from mlflow.utils.autologging_utils import disable_autologging
from optuna import Trial
from pyspark.ml import Pipeline, PipelineModel
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.regression import RandomForestRegressor
from pyspark.sql import SparkSession, DataFrame

from utility_data.utils import time_train_test_split, wape_metric, Config, read_parquet

# %%
config = Config.load_config()
spark = SparkSession \
    .builder \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memory", "1g") \
    .config("spark.sql.shuffle.partitions", "20") \
    .getOrCreate()

mlflow.set_tracking_uri(config.dagshub_uri)
mlflow.set_experiment('PlaneCostPrediction')
mlflow.pyspark.ml.autolog(log_models=False, log_datasets=False)

df = read_parquet(spark, config.hf_dataset, config.hf_read_token, partition_size=5)

all_features = df.columns
cat_features = [name for name, dtype in df.dtypes if dtype == 'string']

df.show(5)
# Out:
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |target_economy|target_comfort|target_business|departure_day|departure_day_of_week|departure_month|is_weekend|departure_hour|duration_hours|count_of_week_routes|airplane_range|economy|comfort|business|avg_book_lead_time|  s2_book_lead_time|count_book_lead_time|is_avg_book_lead_time_missing|  departure_city|departure_country|arrival_city|arrival_country|   airplane_model|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |           326|            48|             30|            1|                    3|             10|         0|             5|             1|                   7|         14600|    326|     48|      30|30.120028891673627|0.05985291147778805|                 133|                            0|           Paris|           France|        Nice|         France| Boeing 777-300ER|
# |           115|             0|             13|            1|                    3|             10|         0|             5|             7|                   1|          7000|    144|      0|      16|30.123078703703705|0.08308504678941933|                   2|                            0|         Beijing|            China|         Goa|          India| Boeing 737 MAX 7|
# |           144|             0|             16|            1|                    3|             10|         0|             7|             1|                   6|          7000|    144|      0|      16|30.177904128086418|0.09870410648688327|                  24|                            0|           Miami|    United States|   Charlotte|  United States| Boeing 737 MAX 7|
# |           281|             0|             44|            1|                    3|             10|         0|             8|             1|                   7|         16700|    281|      0|      44|30.152721522394486|0.09039887194550104|                  43|                            0|Saint Petersburg|           Russia|      Moscow|         Russia|Aerobus A350-1000|
# |           281|             0|             44|            1|                    3|             10|         0|            13|             1|                   6|         16700|    281|      0|      44|30.292628451554236|0.16560835852028494|                 112|                            0|         Orlando|    United States|     Atlanta|  United States|Aerobus A350-1000|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# only showing top 5 rows

# %%
index_cols = [f'{col}_index' for col in cat_features]
exclude_cols = cat_features + ['target_economy', 'target_comfort', 'target_business']

indexer = StringIndexer(inputCols=cat_features, outputCols=index_cols, handleInvalid='keep')
assembler = VectorAssembler(inputCols=[col for col in all_features if col not in exclude_cols] + index_cols, outputCol='features', handleInvalid='keep')

models = {
    'economy': {'labelCol': 'target_economy', 'featuresCol': 'features', 'predictionCol': 'prediction_economy'},
    'comfort': {'labelCol': 'target_comfort', 'featuresCol': 'features', 'predictionCol': 'prediction_comfort'},
    'business': {'labelCol': 'target_business', 'featuresCol': 'features', 'predictionCol': 'prediction_business'},
}

# %%
def objective(trial: Trial, model_name: str, model_cols: dict[str, str], train_data: DataFrame, valid_data: DataFrame):
    params = {
        'maxDepth': trial.suggest_int('maxDepth', 2, 10),
        'maxBins': trial.suggest_int('maxBins', 66, 100),
        'numTrees': trial.suggest_int('numTrees', 1, 25),
        'minInfoGain': trial.suggest_float('minInfoGain', 1e-9, 0.1, log=True),
    }

    with disable_autologging():
        forest = RandomForestRegressor(featuresCol=model_cols['featuresCol'], labelCol=model_cols['labelCol'], predictionCol=model_cols['predictionCol'], **params, seed=config.random_state)
        forest = forest.fit(train_data)
    val_preds = forest.transform(valid_data)

    val_wape = wape_metric(val_preds, label_col=model_cols['labelCol'], prediction_col=model_cols['predictionCol'])
    val_rmse = RegressionEvaluator(predictionCol=model_cols['predictionCol'], labelCol=model_cols['labelCol']).evaluate(val_preds)

    mlflow.log_metric(f'{model_name}_val_rmse', val_rmse, step=trial.number)
    mlflow.log_metric(f'{model_name}_val_wape', val_wape, step=trial.number)

    return val_wape

# %%
with mlflow.start_run(run_name='random_forest', tags={'mlflow.user': 'Alexander'}) as run:
    train, test, train_meta = time_train_test_split(df, 0.25)
    valid, test, valid_meta = time_train_test_split(test, 0.5)

    mlflow.log_params({
        "all_days": train_meta["all_days"],
        "train_days_count": train_meta["train_size"],
        "valid_days_count": valid_meta["train_size"],
        "test_days_count": valid_meta["all_days"] - valid_meta["train_size"]
    })

    print(f"All days = {train_meta['all_days']}\n"
          f"Train days size = {train_meta['train_size']}\n"
          f"Valid days size = {valid_meta['train_size']}\n"
          f"Test days size = {valid_meta['all_days'] - valid_meta['train_size']}")
    print(f"All rows = {df.count()}\n"
          f"Train rows = {train.count()}\n"
          f"Valid rows = {valid.count()}\n"
          f"Test rows = {test.count()}")

    feature_pipeline = Pipeline(stages=[indexer, assembler])
    feature_pipeline = feature_pipeline.fit(train)
    train_piped = feature_pipeline.transform(train).cache()
    valid_piped = feature_pipeline.transform(valid).cache()

    model_stages = []
    for cur_model_name, cur_model_cols in models.items():
        study = optuna.create_study(study_name=f'Optuna_{cur_model_name}_study', direction='minimize')
        study.optimize(lambda trial: objective(trial, cur_model_name, cur_model_cols, train_piped, valid_piped), n_trials=20, show_progress_bar=True)

        print(f"--> {cur_model_name} val WAPE = {study.best_value * 100:.2f}%")

        with disable_autologging():
            model = RandomForestRegressor(
                featuresCol=cur_model_cols['featuresCol'], labelCol=cur_model_cols['labelCol'], predictionCol=cur_model_cols['predictionCol'], **study.best_params, seed=config.random_state
            ).fit(train_piped)
            model_stages.append(model)

    train_piped.unpersist()
    valid_piped.unpersist()

    model_pipeline = PipelineModel(stages=[*feature_pipeline.stages, *model_stages])
    mean_rmse, mean_wape = 0, 0
    preds = model_pipeline.transform(test).cache()

    for cur_model_name, cur_model_cols in models.items():
        rmse = RegressionEvaluator(predictionCol=cur_model_cols['predictionCol'], labelCol=cur_model_cols['labelCol']).evaluate(preds)
        wape = wape_metric(preds, label_col=cur_model_cols['labelCol'], prediction_col=cur_model_cols['predictionCol'])
        print(f'{cur_model_name} predictions\nRMSE = {rmse:.4f}\nWAPE = {wape * 100:.4f}%\n')

        mean_rmse += rmse
        mean_wape += wape

        mlflow.log_metric(f'{cur_model_name} RMSE', rmse)
        mlflow.log_metric(f'{cur_model_name} WAPE', wape)

    mean_rmse /= len(models)
    mean_wape /= len(models)

    print(f'Mean RMSE = {mean_rmse:.4f}\nMean WAPE = {mean_wape * 100:.4f}%\n')

    mlflow.log_metric('Mean RMSE', mean_rmse)
    mlflow.log_metric('Mean WAPE', mean_wape)
    mlflow.spark.log_model(model_pipeline, 'random_forest')
# Out:
# All days = 211
# Train days size = 158
# Valid days size = 26
# Test days size = 27
# All rows = 36552
# Train rows = 27048
# Valid rows = 4706
# Test rows = 4798
# [I 2026-07-14 16:39:21,086] A new study created in memory with name: Optuna_economy_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-14 16:39:34,641] Trial 0 finished with value: 0.12653036763305228 and parameters: {'maxDepth': 9, 'maxBins': 83, 'numTrees': 23, 'minInfoGain': 3.0595104336794243e-06}. Best is trial 0 with value: 0.12653036763305228.
# [I 2026-07-14 16:39:35,925] Trial 1 finished with value: 0.23591408151989413 and parameters: {'maxDepth': 2, 'maxBins': 78, 'numTrees': 20, 'minInfoGain': 1.0494907222433321e-06}. Best is trial 0 with value: 0.12653036763305228.
# [I 2026-07-14 16:39:37,398] Trial 2 finished with value: 0.13312337213161554 and parameters: {'maxDepth': 6, 'maxBins': 79, 'numTrees': 2, 'minInfoGain': 0.002215240142002173}. Best is trial 0 with value: 0.12653036763305228.
# [I 2026-07-14 16:39:38,735] Trial 3 finished with value: 0.1657221448735783 and parameters: {'maxDepth': 5, 'maxBins': 84, 'numTrees': 12, 'minInfoGain': 2.2253682231565945e-07}. Best is trial 0 with value: 0.12653036763305228.
# [I 2026-07-14 16:39:39,843] Trial 4 finished with value: 0.19788936676223398 and parameters: {'maxDepth': 3, 'maxBins': 82, 'numTrees': 2, 'minInfoGain': 2.8074655579158246e-08}. Best is trial 0 with value: 0.12653036763305228.
# [I 2026-07-14 16:39:42,276] Trial 5 finished with value: 0.12025202664178011 and parameters: {'maxDepth': 10, 'maxBins': 67, 'numTrees': 13, 'minInfoGain': 0.008107649198940246}. Best is trial 5 with value: 0.12025202664178011.
# [I 2026-07-14 16:39:43,544] Trial 6 finished with value: 0.1332978176639918 and parameters: {'maxDepth': 6, 'maxBins': 94, 'numTrees': 2, 'minInfoGain': 1.1390878319828876e-08}. Best is trial 5 with value: 0.12025202664178011.
# [I 2026-07-14 16:39:45,043] Trial 7 finished with value: 0.15583126544688763 and parameters: {'maxDepth': 6, 'maxBins': 96, 'numTrees': 18, 'minInfoGain': 0.0031167246978205006}. Best is trial 5 with value: 0.12025202664178011.
# [I 2026-07-14 16:39:46,120] Trial 8 finished with value: 0.2589323903557408 and parameters: {'maxDepth': 2, 'maxBins': 81, 'numTrees': 2, 'minInfoGain': 8.929245514406611e-05}. Best is trial 5 with value: 0.12025202664178011.
# [I 2026-07-14 16:39:47,499] Trial 9 finished with value: 0.14668326302549872 and parameters: {'maxDepth': 7, 'maxBins': 77, 'numTrees': 5, 'minInfoGain': 0.08228012038779593}. Best is trial 5 with value: 0.12025202664178011.
# [I 2026-07-14 16:39:49,696] Trial 10 finished with value: 0.11577269549368858 and parameters: {'maxDepth': 10, 'maxBins': 67, 'numTrees': 11, 'minInfoGain': 5.538023701987454e-05}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:39:51,814] Trial 11 finished with value: 0.12489612856641934 and parameters: {'maxDepth': 10, 'maxBins': 67, 'numTrees': 12, 'minInfoGain': 5.303586375978387e-05}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:39:53,532] Trial 12 finished with value: 0.12375969886307872 and parameters: {'maxDepth': 9, 'maxBins': 66, 'numTrees': 11, 'minInfoGain': 0.0903768692028252}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:39:58,400] Trial 13 finished with value: 0.11800367024948169 and parameters: {'maxDepth': 10, 'maxBins': 71, 'numTrees': 8, 'minInfoGain': 0.0006224254691836732}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:39:59,869] Trial 14 finished with value: 0.12652257178690993 and parameters: {'maxDepth': 8, 'maxBins': 71, 'numTrees': 8, 'minInfoGain': 0.00011492084307688846}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:40:01,664] Trial 15 finished with value: 0.1190476988681596 and parameters: {'maxDepth': 10, 'maxBins': 73, 'numTrees': 8, 'minInfoGain': 1.3941902699376302e-05}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:40:03,456] Trial 16 finished with value: 0.12199925733751053 and parameters: {'maxDepth': 8, 'maxBins': 72, 'numTrees': 16, 'minInfoGain': 0.0008180700462728937}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:40:05,067] Trial 17 finished with value: 0.1268067992255294 and parameters: {'maxDepth': 9, 'maxBins': 73, 'numTrees': 8, 'minInfoGain': 0.0003002474201911525}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:40:11,691] Trial 18 finished with value: 0.12130791784060387 and parameters: {'maxDepth': 8, 'maxBins': 88, 'numTrees': 15, 'minInfoGain': 1.7553604154607718e-09}. Best is trial 10 with value: 0.11577269549368858.
# [I 2026-07-14 16:40:13,359] Trial 19 finished with value: 0.12001164455976739 and parameters: {'maxDepth': 10, 'maxBins': 70, 'numTrees': 6, 'minInfoGain': 5.9882365454141775e-06}. Best is trial 10 with value: 0.11577269549368858.
# --> economy val WAPE = 11.58%
# [I 2026-07-14 16:40:14,615] A new study created in memory with name: Optuna_comfort_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-14 16:40:18,394] Trial 0 finished with value: 0.10973467898302851 and parameters: {'maxDepth': 9, 'maxBins': 75, 'numTrees': 7, 'minInfoGain': 1.0660572317451189e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:22,648] Trial 1 finished with value: 0.12319849962947356 and parameters: {'maxDepth': 7, 'maxBins': 82, 'numTrees': 13, 'minInfoGain': 5.194827654479039e-07}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:23,894] Trial 2 finished with value: 0.13794062015594122 and parameters: {'maxDepth': 8, 'maxBins': 89, 'numTrees': 2, 'minInfoGain': 6.309566929602539e-05}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:30,401] Trial 3 finished with value: 0.11924072302202146 and parameters: {'maxDepth': 9, 'maxBins': 70, 'numTrees': 22, 'minInfoGain': 0.002989738777783342}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:31,722] Trial 4 finished with value: 0.13541149973233366 and parameters: {'maxDepth': 6, 'maxBins': 82, 'numTrees': 17, 'minInfoGain': 7.493336428910413e-08}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:38,400] Trial 5 finished with value: 0.13465594706395495 and parameters: {'maxDepth': 6, 'maxBins': 98, 'numTrees': 25, 'minInfoGain': 1.0574680862002899e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:42,402] Trial 6 finished with value: 0.13547357597391488 and parameters: {'maxDepth': 7, 'maxBins': 80, 'numTrees': 9, 'minInfoGain': 2.765667211552785e-08}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:46,417] Trial 7 finished with value: 0.11303637784141093 and parameters: {'maxDepth': 8, 'maxBins': 92, 'numTrees': 1, 'minInfoGain': 3.7000776131794132e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:50,406] Trial 8 finished with value: 0.12688675637195795 and parameters: {'maxDepth': 7, 'maxBins': 78, 'numTrees': 22, 'minInfoGain': 5.1717556293265295e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:40:54,418] Trial 9 finished with value: 0.12026791448905605 and parameters: {'maxDepth': 9, 'maxBins': 99, 'numTrees': 10, 'minInfoGain': 8.248282441809797e-07}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:02,439] Trial 10 finished with value: 0.323917237483864 and parameters: {'maxDepth': 2, 'maxBins': 68, 'numTrees': 6, 'minInfoGain': 0.04589786876162171}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:06,491] Trial 11 finished with value: 0.1113941812578598 and parameters: {'maxDepth': 10, 'maxBins': 92, 'numTrees': 1, 'minInfoGain': 1.8302622166915925e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:10,426] Trial 12 finished with value: 0.1230376208249085 and parameters: {'maxDepth': 10, 'maxBins': 89, 'numTrees': 5, 'minInfoGain': 1.1957722674688214e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:14,430] Trial 13 finished with value: 0.11606243690041701 and parameters: {'maxDepth': 10, 'maxBins': 74, 'numTrees': 5, 'minInfoGain': 1.4818002905340526e-07}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:15,508] Trial 14 finished with value: 0.17300254207375448 and parameters: {'maxDepth': 4, 'maxBins': 87, 'numTrees': 9, 'minInfoGain': 4.02221503662576e-06}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:22,427] Trial 15 finished with value: 0.11638296481349841 and parameters: {'maxDepth': 10, 'maxBins': 94, 'numTrees': 1, 'minInfoGain': 1.852299288071624e-08}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:26,672] Trial 16 finished with value: 0.12130507323382099 and parameters: {'maxDepth': 9, 'maxBins': 74, 'numTrees': 14, 'minInfoGain': 1.907307909327512e-05}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:34,427] Trial 17 finished with value: 0.1163432112362978 and parameters: {'maxDepth': 8, 'maxBins': 85, 'numTrees': 5, 'minInfoGain': 1.9676117041183167e-08}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:42,451] Trial 18 finished with value: 0.11009767499804878 and parameters: {'maxDepth': 10, 'maxBins': 76, 'numTrees': 7, 'minInfoGain': 1.0180383601340538e-09}. Best is trial 0 with value: 0.10973467898302851.
# [I 2026-07-14 16:41:46,430] Trial 19 finished with value: 0.15677807235682606 and parameters: {'maxDepth': 5, 'maxBins': 75, 'numTrees': 12, 'minInfoGain': 1.0770178832027446e-08}. Best is trial 0 with value: 0.10973467898302851.
# --> comfort val WAPE = 10.97%
# [I 2026-07-14 16:41:47,167] A new study created in memory with name: Optuna_business_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-14 16:41:48,742] Trial 0 finished with value: 0.14133382820931292 and parameters: {'maxDepth': 8, 'maxBins': 79, 'numTrees': 13, 'minInfoGain': 0.0031135773132999565}. Best is trial 0 with value: 0.14133382820931292.
# [I 2026-07-14 16:41:50,714] Trial 1 finished with value: 0.12980586928432666 and parameters: {'maxDepth': 10, 'maxBins': 68, 'numTrees': 9, 'minInfoGain': 3.7676475418533215e-08}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:41:51,821] Trial 2 finished with value: 0.17637710569096968 and parameters: {'maxDepth': 5, 'maxBins': 97, 'numTrees': 6, 'minInfoGain': 2.219608089995898e-09}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:41:52,993] Trial 3 finished with value: 0.16721317047780207 and parameters: {'maxDepth': 6, 'maxBins': 80, 'numTrees': 5, 'minInfoGain': 9.314937913252377e-05}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:41:54,441] Trial 4 finished with value: 0.15732200401265986 and parameters: {'maxDepth': 6, 'maxBins': 95, 'numTrees': 17, 'minInfoGain': 0.028488144262808268}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:42:02,453] Trial 5 finished with value: 0.1602521621618211 and parameters: {'maxDepth': 6, 'maxBins': 69, 'numTrees': 21, 'minInfoGain': 3.710663295293541e-07}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:42:04,271] Trial 6 finished with value: 0.13588419889180686 and parameters: {'maxDepth': 9, 'maxBins': 67, 'numTrees': 14, 'minInfoGain': 9.52113768462865e-05}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:42:06,441] Trial 7 finished with value: 0.17928676438852062 and parameters: {'maxDepth': 5, 'maxBins': 95, 'numTrees': 18, 'minInfoGain': 1.203944147857256e-05}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:42:10,446] Trial 8 finished with value: 0.16774240314011266 and parameters: {'maxDepth': 5, 'maxBins': 70, 'numTrees': 10, 'minInfoGain': 3.678704406345386e-08}. Best is trial 1 with value: 0.12980586928432666.
# [I 2026-07-14 16:42:14,989] Trial 9 finished with value: 0.12325518458276136 and parameters: {'maxDepth': 9, 'maxBins': 69, 'numTrees': 4, 'minInfoGain': 0.0005630145190173699}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:22,436] Trial 10 finished with value: 0.2492411053672779 and parameters: {'maxDepth': 2, 'maxBins': 86, 'numTrees': 25, 'minInfoGain': 0.09425900358653487}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:26,504] Trial 11 finished with value: 0.1303178943648498 and parameters: {'maxDepth': 10, 'maxBins': 75, 'numTrees': 1, 'minInfoGain': 1.851986908575781e-06}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:30,445] Trial 12 finished with value: 0.12971229305012474 and parameters: {'maxDepth': 10, 'maxBins': 72, 'numTrees': 7, 'minInfoGain': 1.0012591693977984e-09}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:31,747] Trial 13 finished with value: 0.12952715013801294 and parameters: {'maxDepth': 8, 'maxBins': 75, 'numTrees': 2, 'minInfoGain': 1.199719689531188e-09}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:34,696] Trial 14 finished with value: 0.13142726914641942 and parameters: {'maxDepth': 8, 'maxBins': 77, 'numTrees': 1, 'minInfoGain': 0.0010936591754903198}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:36,014] Trial 15 finished with value: 0.13867404014089402 and parameters: {'maxDepth': 8, 'maxBins': 84, 'numTrees': 3, 'minInfoGain': 3.1969782467446154e-08}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:42,478] Trial 16 finished with value: 0.13324813162364116 and parameters: {'maxDepth': 7, 'maxBins': 74, 'numTrees': 4, 'minInfoGain': 1.5813017744598293e-06}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:50,456] Trial 17 finished with value: 0.13453157536375185 and parameters: {'maxDepth': 9, 'maxBins': 89, 'numTrees': 9, 'minInfoGain': 0.0006240458196278579}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:51,622] Trial 18 finished with value: 0.2566245041204267 and parameters: {'maxDepth': 2, 'maxBins': 66, 'numTrees': 3, 'minInfoGain': 1.4182696291349962e-05}. Best is trial 9 with value: 0.12325518458276136.
# [I 2026-07-14 16:42:53,287] Trial 19 finished with value: 0.14065896842875686 and parameters: {'maxDepth': 9, 'maxBins': 82, 'numTrees': 7, 'minInfoGain': 9.32685747611277e-09}. Best is trial 9 with value: 0.12325518458276136.
# --> business val WAPE = 12.33%
# economy predictions
# RMSE = 49.7329
# WAPE = 15.1233%
#
# comfort predictions
# RMSE = 6.0267
# WAPE = 14.8350%
#
# business predictions
# RMSE = 6.2204
# WAPE = 14.7133%
#
# Mean RMSE = 20.6600
# Mean WAPE = 14.8906%
# 2026/07/14 16:43:39 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\ALEXAN~1\AppData\Local\Temp\tmpdkivhnrt\model, flavor: spark). Fall back to return ['pyspark==4.1.2']. Set logging level to DEBUG to see the full traceback.
# 2026/07/14 16:43:39 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run random_forest at: https://dagshub.com/jstnoname/PlaneCostPrediction.mlflow/#/experiments/0/runs/43afdb863cb14733a95eb04169d0d004
# 🧪 View experiment at: https://dagshub.com/jstnoname/PlaneCostPrediction.mlflow/#/experiments/0

# %% [markdown]
# Случайный лес показал хороший прирост в метриках, средний WAPE упал с 23% до 15%, средний RMSE упал с 21.4 до 20 билетов. Это произошло из-за того, что случайный лес хорошо ищет нелинейные признаки,
# поэтому разброс между классами обслуживания всего 0,359 процента.

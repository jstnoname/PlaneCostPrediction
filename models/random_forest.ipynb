# %%
from pathlib import Path

import mlflow
import optuna
from mlflow.utils.autologging_utils import disable_autologging
from optuna import Trial
from pyspark.ml import Pipeline, PipelineModel
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.regression import RandomForestRegressor
from pyspark.sql import SparkSession, DataFrame

from utility_data.utils import time_train_test_split, wape_metric, Config

# %%
config = Config()
spark = SparkSession \
    .builder \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memory", "1g") \
    .config("spark.sql.shuffle.partitions", "20") \
    .getOrCreate()

mlflow.set_tracking_uri('http://localhost:5000')
mlflow.set_experiment('PlaneCostPrediction')
mlflow.pyspark.ml.autolog(log_models=False, log_datasets=False)

df_path = Path.cwd().parent / 'data' / 'cleaned_data'
df = spark.read.parquet(str(df_path))

all_features = df.columns
cat_features = [name for name, dtype in df.dtypes if dtype == 'string']

df.show(5)
# Out:
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |target_economy|target_comfort|target_business|departure_day|departure_day_of_week|departure_month|is_weekend|departure_hour|duration_hours|count_of_week_routes|airplane_range|economy|comfort|business|avg_book_lead_time|  s2_book_lead_time|count_book_lead_time|is_avg_book_lead_time_missing|  departure_city|departure_country|arrival_city|arrival_country|   airplane_model|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# |           326|            48|             30|            1|                    3|             10|         0|             5|             1|                   7|         14600|    326|     48|      30|30.120028891673627|0.05985291147778805|                 133|                            0|           Paris|           France|        Nice|         France| Boeing 777-300ER|
# |           115|             0|             13|            1|                    3|             10|         0|             5|             7|                   1|          7000|    144|      0|      16|30.123078703703705|0.08308504678941933|                   2|                            0|         Beijing|            China|         Goa|          India| Boeing 737 MAX 7|
# |           144|             0|             16|            1|                    3|             10|         0|             7|             1|                   6|          7000|    144|      0|      16|30.177904128086418|0.09870410648688327|                  24|                            0|           Miami|    United States|   Charlotte|  United States| Boeing 737 MAX 7|
# |           281|             0|             44|            1|                    3|             10|         0|             8|             1|                   7|         16700|    281|      0|      44|30.152721522394486|0.09039887194550104|                  43|                            0|Saint Petersburg|           Russia|      Moscow|         Russia|Aerobus A350-1000|
# |           281|             0|             44|            1|                    3|             10|         0|            13|             1|                   6|         16700|    281|      0|      44|30.292628451554236|0.16560835852028494|                 112|                            0|         Orlando|    United States|     Atlanta|  United States|Aerobus A350-1000|
# +--------------+--------------+---------------+-------------+---------------------+---------------+----------+--------------+--------------+--------------------+--------------+-------+-------+--------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------+------------+---------------+-----------------+
# only showing top 5 rows

# %%
index_cols = [f'{col}_index' for col in cat_features]
exclude_cols = cat_features + ['target_economy', 'target_comfort', 'target_business']

indexer = StringIndexer(inputCols=cat_features, outputCols=index_cols, handleInvalid='keep')
assembler = VectorAssembler(inputCols=[col for col in all_features if col not in exclude_cols] + index_cols, outputCol='features', handleInvalid='keep')

models = {
    'economy': {'labelCol': 'target_economy', 'featuresCol': 'features', 'predictionCol': 'prediction_economy'},
    'comfort': {'labelCol': 'target_comfort', 'featuresCol': 'features', 'predictionCol': 'prediction_comfort'},
    'business': {'labelCol': 'target_business', 'featuresCol': 'features', 'predictionCol': 'prediction_business'},
}

# %%
def objective(trial: Trial, model_name: str, model_cols: dict[str, str], train_data: DataFrame, valid_data: DataFrame):
    params = {
        'maxDepth': trial.suggest_int('maxDepth', 2, 10),
        'maxBins': trial.suggest_int('maxBins', 66, 100),
        'numTrees': trial.suggest_int('numTrees', 1, 25),
        'minInfoGain': trial.suggest_float('minInfoGain', 1e-9, 0.1, log=True),
    }

    with disable_autologging():
        forest = RandomForestRegressor(featuresCol=model_cols['featuresCol'], labelCol=model_cols['labelCol'], predictionCol=model_cols['predictionCol'], **params, seed=config.random_state)
        forest = forest.fit(train_data)
    val_preds = forest.transform(valid_data)

    val_wape = wape_metric(val_preds, label_col=model_cols['labelCol'], prediction_col=model_cols['predictionCol'])
    val_rmse = RegressionEvaluator(predictionCol=model_cols['predictionCol'], labelCol=model_cols['labelCol']).evaluate(val_preds)

    mlflow.log_metric(f'{model_name}_val_rmse', val_rmse, step=trial.number)
    mlflow.log_metric(f'{model_name}_val_wape', val_wape, step=trial.number)

    return val_wape

# %%
with mlflow.start_run(run_name='random_forest', tags={'mlflow.user': 'Alexander'}) as run:
    train, test, train_meta = time_train_test_split(df, 0.25)
    valid, test, valid_meta = time_train_test_split(test, 0.5)

    mlflow.log_params({
        "all_days": train_meta["all_days"],
        "train_days_count": train_meta["train_size"],
        "valid_days_count": valid_meta["train_size"],
        "test_days_count": valid_meta["all_days"] - valid_meta["train_size"]
    })

    print(f"All days = {train_meta['all_days']}\n"
          f"Train days size = {train_meta['train_size']}\n"
          f"Valid days size = {valid_meta['train_size']}\n"
          f"Test days size = {valid_meta['all_days'] - valid_meta['train_size']}")
    print(f"All rows = {df.count()}\n"
          f"Train rows = {train.count()}\n"
          f"Valid rows = {valid.count()}\n"
          f"Test rows = {test.count()}")

    feature_pipeline = Pipeline(stages=[indexer, assembler])
    feature_pipeline = feature_pipeline.fit(train)
    train_piped = feature_pipeline.transform(train).cache()
    valid_piped = feature_pipeline.transform(valid).cache()

    model_stages = []
    for cur_model_name, cur_model_cols in models.items():
        study = optuna.create_study(study_name=f'Optuna_{cur_model_name}_study', direction='minimize')
        study.optimize(lambda trial: objective(trial, cur_model_name, cur_model_cols, train_piped, valid_piped), n_trials=20, show_progress_bar=True)

        print(f"--> {cur_model_name} val WAPE = {study.best_value * 100:.2f}%")

        with disable_autologging():
            model = RandomForestRegressor(
                featuresCol=cur_model_cols['featuresCol'], labelCol=cur_model_cols['labelCol'], predictionCol=cur_model_cols['predictionCol'], **study.best_params, seed=config.random_state
            ).fit(train_piped)
            model_stages.append(model)

    train_piped.unpersist()
    valid_piped.unpersist()

    model_pipeline = PipelineModel(stages=[*feature_pipeline.stages, *model_stages])
    mean_rmse, mean_wape = 0, 0
    preds = model_pipeline.transform(test).cache()

    for cur_model_name, cur_model_cols in models.items():
        rmse = RegressionEvaluator(predictionCol=cur_model_cols['predictionCol'], labelCol=cur_model_cols['labelCol']).evaluate(preds)
        wape = wape_metric(preds, label_col=cur_model_cols['labelCol'], prediction_col=cur_model_cols['predictionCol'])
        print(f'{cur_model_name} predictions\nRMSE = {rmse:.4f}\nWAPE = {wape * 100:.4f}%\n')

        mean_rmse += rmse
        mean_wape += wape

        mlflow.log_metric(f'{cur_model_name} RMSE', rmse)
        mlflow.log_metric(f'{cur_model_name} WAPE', wape)

    mean_rmse /= len(models)
    mean_wape /= len(models)

    print(f'Mean RMSE = {mean_rmse:.4f}\nMean WAPE = {mean_wape * 100:.4f}%\n')

    mlflow.log_metric('Mean RMSE', mean_rmse)
    mlflow.log_metric('Mean WAPE', mean_wape)
    mlflow.spark.log_model(model_pipeline, 'random_forest')
# Out:
# All days = 211
# Train days size = 158
# Valid days size = 26
# Test days size = 27
# All rows = 36552
# Train rows = 27048
# Valid rows = 4706
# Test rows = 4798
# [I 2026-07-12 16:59:06,726] A new study created in memory with name: Optuna_economy_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-12 16:59:13,020] Trial 0 finished with value: 0.12601337076374372 and parameters: {'maxDepth': 9, 'maxBins': 69, 'numTrees': 1, 'minInfoGain': 4.0814553576160707e-05}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:14,967] Trial 1 finished with value: 0.1631633378253432 and parameters: {'maxDepth': 5, 'maxBins': 82, 'numTrees': 19, 'minInfoGain': 2.2793324819414242e-05}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:16,621] Trial 2 finished with value: 0.13065880803332014 and parameters: {'maxDepth': 8, 'maxBins': 98, 'numTrees': 7, 'minInfoGain': 2.2969073821640477e-06}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:17,733] Trial 3 finished with value: 0.1440732898182257 and parameters: {'maxDepth': 7, 'maxBins': 83, 'numTrees': 4, 'minInfoGain': 3.659856294871444e-05}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:19,150] Trial 4 finished with value: 0.13831232400216065 and parameters: {'maxDepth': 7, 'maxBins': 92, 'numTrees': 24, 'minInfoGain': 0.0419533268834938}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:19,811] Trial 5 finished with value: 0.2507552865272737 and parameters: {'maxDepth': 2, 'maxBins': 83, 'numTrees': 4, 'minInfoGain': 4.412379744857291e-06}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:20,460] Trial 6 finished with value: 0.2507552865272737 and parameters: {'maxDepth': 2, 'maxBins': 98, 'numTrees': 4, 'minInfoGain': 0.0021066073869968386}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:21,147] Trial 7 finished with value: 0.23616633894753566 and parameters: {'maxDepth': 2, 'maxBins': 71, 'numTrees': 14, 'minInfoGain': 9.000562051539867e-08}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:22,445] Trial 8 finished with value: 0.138139102156195 and parameters: {'maxDepth': 7, 'maxBins': 81, 'numTrees': 19, 'minInfoGain': 4.9897339429535965e-05}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:24,103] Trial 9 finished with value: 0.1273139584594746 and parameters: {'maxDepth': 10, 'maxBins': 99, 'numTrees': 8, 'minInfoGain': 5.270518252991192e-05}. Best is trial 0 with value: 0.12601337076374372.
# [I 2026-07-12 16:59:26,053] Trial 10 finished with value: 0.11925754080809695 and parameters: {'maxDepth': 10, 'maxBins': 66, 'numTrees': 12, 'minInfoGain': 4.9460234085753286e-09}. Best is trial 10 with value: 0.11925754080809695.
# [I 2026-07-12 16:59:27,891] Trial 11 finished with value: 0.12081128786083828 and parameters: {'maxDepth': 10, 'maxBins': 66, 'numTrees': 11, 'minInfoGain': 1.4378284060439479e-09}. Best is trial 10 with value: 0.11925754080809695.
# [I 2026-07-12 16:59:29,619] Trial 12 finished with value: 0.12081128786083828 and parameters: {'maxDepth': 10, 'maxBins': 66, 'numTrees': 11, 'minInfoGain': 1.127177579082978e-09}. Best is trial 10 with value: 0.11925754080809695.
# [I 2026-07-12 16:59:31,542] Trial 13 finished with value: 0.11566272451503051 and parameters: {'maxDepth': 10, 'maxBins': 74, 'numTrees': 14, 'minInfoGain': 1.0153651462114972e-09}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:33,229] Trial 14 finished with value: 0.11728208815076334 and parameters: {'maxDepth': 9, 'maxBins': 75, 'numTrees': 16, 'minInfoGain': 2.5986397537873584e-08}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:34,647] Trial 15 finished with value: 0.13525040120971926 and parameters: {'maxDepth': 8, 'maxBins': 74, 'numTrees': 17, 'minInfoGain': 6.846741823824229e-08}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:35,576] Trial 16 finished with value: 0.16336093200565657 and parameters: {'maxDepth': 5, 'maxBins': 77, 'numTrees': 24, 'minInfoGain': 3.1278548557918745e-08}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:37,202] Trial 17 finished with value: 0.13579505794999464 and parameters: {'maxDepth': 9, 'maxBins': 77, 'numTrees': 15, 'minInfoGain': 4.302051722309171e-07}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:39,074] Trial 18 finished with value: 0.12374387957144603 and parameters: {'maxDepth': 9, 'maxBins': 88, 'numTrees': 21, 'minInfoGain': 1.2016488240702292e-08}. Best is trial 13 with value: 0.11566272451503051.
# [I 2026-07-12 16:59:39,936] Trial 19 finished with value: 0.16080602164224844 and parameters: {'maxDepth': 5, 'maxBins': 74, 'numTrees': 16, 'minInfoGain': 3.3091240693347333e-07}. Best is trial 13 with value: 0.11566272451503051.
# --> economy val WAPE = 11.57%
# [I 2026-07-12 16:59:41,652] A new study created in memory with name: Optuna_comfort_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-12 16:59:43,287] Trial 0 finished with value: 0.11165433008190813 and parameters: {'maxDepth': 9, 'maxBins': 99, 'numTrees': 15, 'minInfoGain': 2.7039704063417256e-06}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:44,410] Trial 1 finished with value: 0.12854386058234815 and parameters: {'maxDepth': 8, 'maxBins': 83, 'numTrees': 9, 'minInfoGain': 0.00047842463875363427}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:45,462] Trial 2 finished with value: 0.12940416438010932 and parameters: {'maxDepth': 7, 'maxBins': 94, 'numTrees': 15, 'minInfoGain': 1.0193100246496734e-09}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:46,269] Trial 3 finished with value: 0.1449976009103427 and parameters: {'maxDepth': 5, 'maxBins': 85, 'numTrees': 2, 'minInfoGain': 4.6140500386684525e-08}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:47,625] Trial 4 finished with value: 0.1253135673274118 and parameters: {'maxDepth': 8, 'maxBins': 82, 'numTrees': 19, 'minInfoGain': 2.9443149138804817e-07}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:49,325] Trial 5 finished with value: 0.11706110623242891 and parameters: {'maxDepth': 9, 'maxBins': 88, 'numTrees': 22, 'minInfoGain': 0.0034300330204539912}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:50,064] Trial 6 finished with value: 0.21933911658190047 and parameters: {'maxDepth': 3, 'maxBins': 83, 'numTrees': 18, 'minInfoGain': 1.1370341662735244e-06}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:51,583] Trial 7 finished with value: 0.14733638452661757 and parameters: {'maxDepth': 6, 'maxBins': 66, 'numTrees': 24, 'minInfoGain': 0.011543308946035011}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:52,592] Trial 8 finished with value: 0.1435754614864435 and parameters: {'maxDepth': 6, 'maxBins': 81, 'numTrees': 14, 'minInfoGain': 3.059036016223901e-05}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:53,349] Trial 9 finished with value: 0.14982865419292202 and parameters: {'maxDepth': 5, 'maxBins': 74, 'numTrees': 6, 'minInfoGain': 0.00037785263226976327}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:53,972] Trial 10 finished with value: 0.2977887571661323 and parameters: {'maxDepth': 2, 'maxBins': 99, 'numTrees': 10, 'minInfoGain': 3.2677325932329957e-09}. Best is trial 0 with value: 0.11165433008190813.
# [I 2026-07-12 16:59:56,240] Trial 11 finished with value: 0.11011676178292001 and parameters: {'maxDepth': 10, 'maxBins': 93, 'numTrees': 25, 'minInfoGain': 0.05015557580672547}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 16:59:58,316] Trial 12 finished with value: 0.11549891456670078 and parameters: {'maxDepth': 10, 'maxBins': 99, 'numTrees': 21, 'minInfoGain': 2.2083312012969215e-05}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:00,524] Trial 13 finished with value: 0.1135768412398463 and parameters: {'maxDepth': 10, 'maxBins': 92, 'numTrees': 25, 'minInfoGain': 0.0766236219151287}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:01,905] Trial 14 finished with value: 0.11405714682060154 and parameters: {'maxDepth': 9, 'maxBins': 94, 'numTrees': 15, 'minInfoGain': 1.1961240842088458e-05}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:03,453] Trial 15 finished with value: 0.12370123412710542 and parameters: {'maxDepth': 10, 'maxBins': 100, 'numTrees': 11, 'minInfoGain': 2.8393869547356817e-08}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:04,374] Trial 16 finished with value: 0.13366876680816456 and parameters: {'maxDepth': 8, 'maxBins': 90, 'numTrees': 2, 'minInfoGain': 1.781721634632771e-06}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:05,842] Trial 17 finished with value: 0.12027656636583788 and parameters: {'maxDepth': 9, 'maxBins': 96, 'numTrees': 18, 'minInfoGain': 0.07165768346784095}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:06,714] Trial 18 finished with value: 0.13444241420838188 and parameters: {'maxDepth': 7, 'maxBins': 88, 'numTrees': 6, 'minInfoGain': 0.00032822493667735504}. Best is trial 11 with value: 0.11011676178292001.
# [I 2026-07-12 17:00:08,292] Trial 19 finished with value: 0.11446057903133679 and parameters: {'maxDepth': 10, 'maxBins': 77, 'numTrees': 13, 'minInfoGain': 0.002022701717892727}. Best is trial 11 with value: 0.11011676178292001.
# --> comfort val WAPE = 11.01%
# [I 2026-07-12 17:00:10,200] A new study created in memory with name: Optuna_business_study
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-07-12 17:00:12,189] Trial 0 finished with value: 0.12955939280241435 and parameters: {'maxDepth': 9, 'maxBins': 82, 'numTrees': 22, 'minInfoGain': 3.3328977078510836e-06}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:13,683] Trial 1 finished with value: 0.14380760913173113 and parameters: {'maxDepth': 7, 'maxBins': 72, 'numTrees': 20, 'minInfoGain': 1.696605379212971e-05}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:15,858] Trial 2 finished with value: 0.133883818888936 and parameters: {'maxDepth': 9, 'maxBins': 73, 'numTrees': 19, 'minInfoGain': 1.62506009557346e-06}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:17,416] Trial 3 finished with value: 0.14112552599729505 and parameters: {'maxDepth': 8, 'maxBins': 72, 'numTrees': 19, 'minInfoGain': 9.833273950392287e-05}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:18,451] Trial 4 finished with value: 0.15507905127394145 and parameters: {'maxDepth': 7, 'maxBins': 81, 'numTrees': 10, 'minInfoGain': 1.370146159893131e-07}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:19,308] Trial 5 finished with value: 0.17145080212769517 and parameters: {'maxDepth': 5, 'maxBins': 72, 'numTrees': 5, 'minInfoGain': 0.046804941856240456}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:20,253] Trial 6 finished with value: 0.15546973446356377 and parameters: {'maxDepth': 7, 'maxBins': 82, 'numTrees': 6, 'minInfoGain': 5.9767611593068926e-05}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:20,990] Trial 7 finished with value: 0.15988810353724098 and parameters: {'maxDepth': 6, 'maxBins': 71, 'numTrees': 2, 'minInfoGain': 1.0090839168259312e-08}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:21,789] Trial 8 finished with value: 0.17648417449654982 and parameters: {'maxDepth': 5, 'maxBins': 90, 'numTrees': 12, 'minInfoGain': 4.749670813615295e-06}. Best is trial 0 with value: 0.12955939280241435.
# [I 2026-07-12 17:00:23,701] Trial 9 finished with value: 0.12891303375399263 and parameters: {'maxDepth': 9, 'maxBins': 72, 'numTrees': 22, 'minInfoGain': 4.593375043746195e-08}. Best is trial 9 with value: 0.12891303375399263.
# [I 2026-07-12 17:00:24,392] Trial 10 finished with value: 0.2549754173450949 and parameters: {'maxDepth': 2, 'maxBins': 100, 'numTrees': 14, 'minInfoGain': 0.014730032826846597}. Best is trial 9 with value: 0.12891303375399263.
# [I 2026-07-12 17:00:27,637] Trial 11 finished with value: 0.12580302257471931 and parameters: {'maxDepth': 10, 'maxBins': 81, 'numTrees': 25, 'minInfoGain': 1.972324266406861e-09}. Best is trial 11 with value: 0.12580302257471931.
# [I 2026-07-12 17:00:30,449] Trial 12 finished with value: 0.13017261613660855 and parameters: {'maxDepth': 10, 'maxBins': 78, 'numTrees': 24, 'minInfoGain': 1.496106101703852e-09}. Best is trial 11 with value: 0.12580302257471931.
# [I 2026-07-12 17:00:33,402] Trial 13 finished with value: 0.12781262904751775 and parameters: {'maxDepth': 10, 'maxBins': 67, 'numTrees': 25, 'minInfoGain': 4.096590886728949e-08}. Best is trial 11 with value: 0.12580302257471931.
# [I 2026-07-12 17:00:36,399] Trial 14 finished with value: 0.12546358429936 and parameters: {'maxDepth': 10, 'maxBins': 90, 'numTrees': 25, 'minInfoGain': 3.1501821484398044e-09}. Best is trial 14 with value: 0.12546358429936.
# [I 2026-07-12 17:00:38,528] Trial 15 finished with value: 0.13235527834903624 and parameters: {'maxDepth': 10, 'maxBins': 91, 'numTrees': 16, 'minInfoGain': 1.7828276728702157e-09}. Best is trial 14 with value: 0.12546358429936.
# [I 2026-07-12 17:00:40,168] Trial 16 finished with value: 0.13604765138474156 and parameters: {'maxDepth': 8, 'maxBins': 90, 'numTrees': 25, 'minInfoGain': 1.0543052433663382e-09}. Best is trial 14 with value: 0.12546358429936.
# [I 2026-07-12 17:00:40,810] Trial 17 finished with value: 0.2517549058458665 and parameters: {'maxDepth': 2, 'maxBins': 96, 'numTrees': 22, 'minInfoGain': 3.247433157546626e-07}. Best is trial 14 with value: 0.12546358429936.
# [I 2026-07-12 17:00:42,952] Trial 18 finished with value: 0.13194634870185873 and parameters: {'maxDepth': 10, 'maxBins': 86, 'numTrees': 17, 'minInfoGain': 1.1212322362831188e-08}. Best is trial 14 with value: 0.12546358429936.
# [I 2026-07-12 17:00:44,470] Trial 19 finished with value: 0.1375416188561943 and parameters: {'maxDepth': 8, 'maxBins': 87, 'numTrees': 23, 'minInfoGain': 9.057387605760963e-09}. Best is trial 14 with value: 0.12546358429936.
# --> business val WAPE = 12.55%
# economy predictions
# RMSE = 48.1069
# WAPE = 15.1666%
#
# comfort predictions
# RMSE = 5.8466
# WAPE = 14.7861%
#
# business predictions
# RMSE = 5.9993
# WAPE = 14.8076%
#
# Mean RMSE = 19.9843
# Mean WAPE = 14.9201%
# 2026/07/12 17:01:17 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\ALEXAN~1\AppData\Local\Temp\tmpntbw1sv1\model, flavor: spark). Fall back to return ['pyspark==4.1.2']. Set logging level to DEBUG to see the full traceback.
# 2026/07/12 17:01:17 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run random_forest at: http://localhost:5000/#/experiments/1/runs/3ac68ebf340c402e8bd025dbe412d93c
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Случайный лес показал хороший прирост в метриках, средний WAPE упал с 23% до 15%, средний RMSE упал с 21.4 до 20 билетов. Это произошло из-за того, что случайный лес хорошо ищет нелинейные признаки,
# поэтому разброс между классами обслуживания всего 0,359 процента.
